# %%
import sys
sys.path.insert(0, '/Users/david/galvanize/super_liga_xg')

# %%
import pprint
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from scraping_tools.html_scraper import db
from data_preparation import ConvertData

# %%
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # 1) Pulling shot data from mongo_db and preparing for modeling
#
#
#  - **games** - game data scraped from afa
#
#  - use the ConvertData class to remove penalty kicks and create a dataframe with angle and distance

# %%
games = db['games_update'].find()

# %%
cd = ConvertData()

# %%
df = cd.games_to_df(games)

# %%
df.head()
# Out:
#   game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0  448548    99779.0           6.67           0.00           1.51
# 1  448548    60730.0          21.33          12.00           4.24
# 2  448548   177285.0          12.00           1.78           0.00
# 3  448548   185745.0           8.44           0.89          14.53
# 4  448548    77892.0          22.22           0.44          13.92
#
#    shot_coord_y2 shot_coord_z1  shot_coord_z2   shot_id shot_type team_id  \
# 0          -1.21            -1           0.83  22336297        11      20
# 1          -0.91            -1           0.73  22336386        35      20
# 2          -3.03            -1           0.21  22336583        13      20
# 3          -6.66            -1          -1.00  22336723        33      20
# 4          -8.48            -1          -1.00  22336739        33      13
#
#    time_of_event(min)  passed_from_id  pass_coord_x1  pass_coord_x2  \
# 0            1.033333        177285.0           0.89          12.44
# 1            9.683333             NaN            NaN            NaN
# 2           26.833333             NaN            NaN            NaN
# 3           38.883333        177285.0          22.67           6.22
# 4           40.083333             NaN            NaN            NaN
#
#    pass_coord_y1  pass_coord_y2  pass_coord_z1  pass_coord_z2  corner_kick  \
# 0          29.36          -4.84           -1.0           -1.0          1.0
# 1            NaN            NaN            NaN            NaN          0.0
# 2            NaN            NaN            NaN            NaN          0.0
# 3           3.93          19.67           -1.0           -1.0          0.0
# 4            NaN            NaN            NaN            NaN          0.0
#
#    shot_distance  shot_angle  assisted_shot  is_penalty_attempt is_goal
# 0       6.838786   12.755990            1.0                 0.0       1
# 1      21.747333   11.242763            0.0                 0.0       0
# 2      12.000000    0.000000            0.0                 1.0       1
# 3      16.803407   59.849102            1.0                 0.0       0
# 4      26.220122   32.065607            0.0                 0.0       0

# %%
df_no_pen = cd.drop_penalties(df)

# %%
df_no_pen['is_penalty_attempt'].unique()
# Out:
# array([0.])

# %%
df_no_pen.head()
# Out:
#   game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0  448548    99779.0           6.67           0.00           1.51
# 1  448548    60730.0          21.33          12.00           4.24
# 3  448548   185745.0           8.44           0.89          14.53
# 4  448548    77892.0          22.22           0.44          13.92
# 5  448548    77892.0          11.56           0.44          10.59
#
#    shot_coord_y2 shot_coord_z1  shot_coord_z2   shot_id shot_type team_id  \
# 0          -1.21            -1           0.83  22336297        11      20
# 1          -0.91            -1           0.73  22336386        35      20
# 3          -6.66            -1          -1.00  22336723        33      20
# 4          -8.48            -1          -1.00  22336739        33      13
# 5          -1.21            -1           0.14  22336802        35      13
#
#    time_of_event(min)  passed_from_id  pass_coord_x1  pass_coord_x2  \
# 0            1.033333        177285.0           0.89          12.44
# 1            9.683333             NaN            NaN            NaN
# 3           38.883333        177285.0          22.67           6.22
# 4           40.083333             NaN            NaN            NaN
# 5           44.483333             NaN            NaN            NaN
#
#    pass_coord_y1  pass_coord_y2  pass_coord_z1  pass_coord_z2  corner_kick  \
# 0          29.36          -4.84           -1.0           -1.0          1.0
# 1            NaN            NaN            NaN            NaN          0.0
# 3           3.93          19.67           -1.0           -1.0          0.0
# 4            NaN            NaN            NaN            NaN          0.0
# 5            NaN            NaN            NaN            NaN          0.0
#
#    shot_distance  shot_angle  assisted_shot  is_penalty_attempt is_goal
# 0       6.838786   12.755990            1.0                 0.0       1
# 1      21.747333   11.242763            0.0                 0.0       0
# 3      16.803407   59.849102            1.0                 0.0       0
# 4      26.220122   32.065607            0.0                 0.0       0
# 5      15.677426   42.492487            0.0                 0.0       0

# %%
X, y, shot_df = cd.create_xy_prep(df_no_pen)

# %%
len(X) == len(y)
# Out:
# True

# %%
shot_df.head()
# Out:
#    player_id  shot_distance  shot_angle  assisted_shot is_goal  passed_from_id
# 0    99779.0       6.838786   12.755990            1.0       1        177285.0
# 1    60730.0      21.747333   11.242763            0.0       0             NaN
# 3   185745.0      16.803407   59.849102            1.0       0        177285.0
# 4    77892.0      26.220122   32.065607            0.0       0             NaN
# 5    77892.0      15.677426   42.492487            0.0       0             NaN

# %% [markdown]
# # 2) Performance w K-folds
#
# - testing models with k-folds using class **KfoldComparison**

# %%
from kfold_comp import KfoldComparison
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import  RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
import numpy as np

# %%
rf_model = RandomForestClassifier(n_estimators=300, max_depth=3, verbose=1, random_state=8)
xgb_model = XGBClassifier(learning_rate = 0.01, max_depth = 3, n_estimators = 300, random_state=8)
gb_model = GradientBoostingClassifier(learning_rate=0.01, max_depth=4, max_features='log2', min_samples_leaf=4, n_estimators=280, subsample=0.25, random_state=8)

# %%
kc = KfoldComparison(rf_model, xgb_model, gb_model)

# %%
model_performance = kc.kfold_performance(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished

# %%
model_performance
# Out:
# {'RandomForestClassifier': {'scores over k splits': [0.3149713911042562,
#    0.2636513141657711,
#    0.3040402096857578,
#    0.29712475941876354,
#    0.3005702607592707],
#   'mean score': 0.29607158702676384},
#  'XGBClassifier': {'scores over k splits': [0.29742322304998253,
#    0.2979889754425077,
#    0.28724235401981896,
#    0.3045713711256052,
#    0.28529447453187035],
#   'mean score': 0.29450407963395697},
#  'GradientBoostingClassifier': {'scores over k splits': [0.3271802094644408,
#    0.3013947350839168,
#    0.2704248914122688,
#    0.2988636679806667,
#    0.28008830278342844],
#   'mean score': 0.2955903613449443}}

# %% [markdown]
# # 3) Tuning
#
# - tuning models with classes **XGBoostTuner** and **GradientBoostTuner**
# which return the best parameters
#
# - **XGBoostTuner** mostly tries to find the optimum number of trees to use
#
# - **GradientBoostTuner** tries to find optimum depth and trees

# %%
from kfold_comp import XGBoostTuner

# %%
xt = XGBoostTuner()

# %%
xgb_scores = xt.xgb_kfolds(X, y, [2, 4, 6, 8, 10])

# %%
xgb_scores
# Out:
# {'200 trees': {'scores over k splits': [0.2874898967826191,
#    0.3490284290493411,
#    0.2980123454924015,
#    0.29767147901961033,
#    0.31995879765462804],
#   'mean score': 0.31043218959972},
#  '400 trees': {'scores over k splits': [0.2605528539074037,
#    0.34405877026455367,
#    0.27925538145937023,
#    0.2778363951098393,
#    0.31115669882492836],
#   'mean score': 0.294572019913219},
#  '600 trees': {'scores over k splits': [0.25881029254866433,
#    0.3444324420450036,
#    0.27905709477661944,
#    0.2768513196367113,
#    0.3149907238567481],
#   'mean score': 0.2948283745727494},
#  '800 trees': {'scores over k splits': [0.26050570097149295,
#    0.34498552118345877,
#    0.2816377310000141,
#    0.2770806888118386,
#    0.31873514976857203],
#   'mean score': 0.29658895834707527},
#  '1000 trees': {'scores over k splits': [0.26341014305704874,
#    0.34625900492674727,
#    0.2839268844876,
#    0.2774962175425197,
#    0.3223262389350973],
#   'mean score': 0.29868369778980264}}

# %%
xt.best_params()
# Out:
# (0.294572019913219, '400 trees')

# %%
from kfold_comp import GradientBoostTuner

# %%
gbt = GradientBoostTuner()

# %%
gb_dict = gbt.gb_kfolds(X, y)

# %%
gb_dict
# Out:
# {'Depth 1': {'scores over ksplits': [0.2867283851105929,
#    0.27257365523508786,
#    0.30065276635523697,
#    0.29594353031072335,
#    0.30323409759498593],
#   'mean score': 0.2918264869213254,
#   'number of trees': [297, 299, 299, 299, 299]},
#  'Depth 2': {'scores over ksplits': [0.28717272896425666,
#    0.27286310096060007,
#    0.29911930688220634,
#    0.2977213804873199,
#    0.3041691252116337],
#   'mean score': 0.2922091285012033,
#   'number of trees': [184, 299, 299, 227, 174]},
#  'Depth 3': {'scores over ksplits': [0.28929676487784156,
#    0.2726133669237597,
#    0.2969224476774046,
#    0.29877614279497366,
#    0.3067571695939947],
#   'mean score': 0.29287317837359483,
#   'number of trees': [210, 248, 201, 283, 141]},
#  'Depth 4': {'scores over ksplits': [0.2935895595799618,
#    0.27211507575302707,
#    0.2959830146108543,
#    0.30202976077568733,
#    0.31177094520333226],
#   'mean score': 0.29509767118457253,
#   'number of trees': [175, 201, 181, 136, 155]},
#  'Depth 5': {'scores over ksplits': [0.2959295897788324,
#    0.27120900416950494,
#    0.3012985126163226,
#    0.3029211104463409,
#    0.3126336488587048],
#   'mean score': 0.29679837317394114,
#   'number of trees': [131, 254, 181, 110, 123]},
#  'Depth 6': {'scores over ksplits': [0.302231082664926,
#    0.27448548965202935,
#    0.30307916972677407,
#    0.30607443088066105,
#    0.3154963953188216],
#   'mean score': 0.30027331364864246,
#   'number of trees': [71, 167, 146, 137, 83]}}

# %%
gbt.best_params()
# Out:
# ('Depth 1', 0.2918264869213254, 298.6)

# %% [markdown]
# # 4) Comparing Tuned Models

# %%
xgboost_model = XGBClassifier(learning_rate = 0.01, max_depth = 3, n_estimators = 400, random_state=8)
gradient_boost_model = GradientBoostingClassifier(learning_rate=0.01, max_depth=1, max_features='log2', min_samples_leaf=4, n_estimators=289, subsample=0.25, random_state=8)
random_forest_model = RandomForestClassifier(n_estimators=300, max_depth=3, verbose=1, random_state=8)

# %%
kc_tuned = KfoldComparison(random_forest_model, xgboost_model, gradient_boost_model)

# %%
tuned_model_performance = kc_tuned.kfold_performance(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
tuned_model_performance
# Out:
# {'RandomForestClassifier': {'scores over k splits': [0.2838666609627266,
#    0.2922136434742553,
#    0.2715770727173166,
#    0.2948221475281708,
#    0.3444177382164638],
#   'mean score': 0.29737945257978665},
#  'XGBClassifier': {'scores over k splits': [0.3059662556878346,
#    0.2956984673380194,
#    0.25288013898055345,
#    0.32361343742676957,
#    0.29681060175426494],
#   'mean score': 0.2949937802374884},
#  'GradientBoostingClassifier': {'scores over k splits': [0.3026880393713121,
#    0.2819768329288177,
#    0.3314508966783307,
#    0.2797910404693059,
#    0.30491131068184407],
#   'mean score': 0.3001636240259221}}

# %%
model_performance
# Out:
# {'RandomForestClassifier': {'scores over k splits': [0.3149713911042562,
#    0.2636513141657711,
#    0.3040402096857578,
#    0.29712475941876354,
#    0.3005702607592707],
#   'mean score': 0.29607158702676384},
#  'XGBClassifier': {'scores over k splits': [0.29742322304998253,
#    0.2979889754425077,
#    0.28724235401981896,
#    0.3045713711256052,
#    0.28529447453187035],
#   'mean score': 0.29450407963395697},
#  'GradientBoostingClassifier': {'scores over k splits': [0.3271802094644408,
#    0.3013947350839168,
#    0.2704248914122688,
#    0.2988636679806667,
#    0.28008830278342844],
#   'mean score': 0.2955903613449443}}

# %% [markdown]
# 2/3 tuned_model_performance perform better - xgboost is the best

# %% [markdown]
# # Modeling on all
#
# - call on **ExpectedGoal** class to predict_prob of every shot
#
# -

# %%
from xg import ExpectedGoal

# %%
shot_df.head()
# Out:
#    player_id  shot_distance  shot_angle  assisted_shot is_goal  passed_from_id
# 0    99779.0       6.838786   12.755990            1.0       1        177285.0
# 1    60730.0      21.747333   11.242763            0.0       0             NaN
# 3   185745.0      16.803407   59.849102            1.0       0        177285.0
# 4    77892.0      26.220122   32.065607            0.0       0             NaN
# 5    77892.0      15.677426   42.492487            0.0       0             NaN

# %%
eg = ExpectedGoal(random_forest_model, xgboost_model, gradient_boost_model, shot_df)

# %%
eg.predict_prob()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished
# /Users/david/galvanize/super_liga_xg/src/xg.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.df['xG'] = p_ensemble[:, 1]

# %%
total_df = eg.xg_and_xa()

# %%
total_df.head()
# Out:
#      player_id  total_xG  goals  total_xA  total_xG+xA
# 125    24256.0      5.47     12      0.48         5.95
# 113      488.0      3.07      8      0.35         3.42
# 234   119431.0      1.87      6      1.56         3.43
# 83    136659.0      1.81      5      0.48         2.29
# 344   172801.0      2.09      5      0.24         2.33

# %%
total_df['total_xG'].sum()
# Out:
# 342.92999999999995

# %%
total_df['goals'].sum()
# Out:
# 342

# %%
shot_df.head()
# Out:
#    player_id  shot_distance  shot_angle  assisted_shot is_goal  \
# 0    99779.0       6.838786   12.755990            1.0       1
# 1    60730.0      21.747333   11.242763            0.0       0
# 3   185745.0      16.803407   59.849102            1.0       0
# 4    77892.0      26.220122   32.065607            0.0       0
# 5    77892.0      15.677426   42.492487            0.0       0
#
#    passed_from_id        xG
# 0        177285.0  0.372237
# 1             NaN  0.062208
# 3        177285.0  0.064829
# 4             NaN  0.050683
# 5             NaN  0.073719

# %%
df_no_pen = eg.transform_coordinate_xg(df_no_pen)

# %%
df_no_pen.head()
# Out:
#   game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0  448548    99779.0           6.67           0.00           1.51
# 1  448548    60730.0          21.33          12.00           4.24
# 3  448548   185745.0           8.44           0.89          14.53
# 4  448548    77892.0          22.22           0.44          13.92
# 5  448548    77892.0          11.56           0.44          10.59
#
#    shot_coord_y2 shot_coord_z1  shot_coord_z2   shot_id shot_type team_id  \
# 0          -1.21            -1           0.83  22336297        11      20
# 1          -0.91            -1           0.73  22336386        35      20
# 3          -6.66            -1          -1.00  22336723        33      20
# 4          -8.48            -1          -1.00  22336739        33      13
# 5          -1.21            -1           0.14  22336802        35      13
#
#    time_of_event(min)  passed_from_id  pass_coord_x1  pass_coord_x2  \
# 0            1.033333        177285.0           0.89          12.44
# 1            9.683333             NaN            NaN            NaN
# 3           38.883333        177285.0          22.67           6.22
# 4           40.083333             NaN            NaN            NaN
# 5           44.483333             NaN            NaN            NaN
#
#    pass_coord_y1  pass_coord_y2  pass_coord_z1  pass_coord_z2  corner_kick  \
# 0          29.36          -4.84           -1.0           -1.0          1.0
# 1            NaN            NaN            NaN            NaN          0.0
# 3           3.93          19.67           -1.0           -1.0          0.0
# 4            NaN            NaN            NaN            NaN          0.0
# 5            NaN            NaN            NaN            NaN          0.0
#
#    shot_distance  shot_angle  assisted_shot  is_penalty_attempt is_goal  \
# 0       6.838786   12.755990            1.0                 0.0       1
# 1      21.747333   11.242763            0.0                 0.0       0
# 3      16.803407   59.849102            1.0                 0.0       0
# 4      26.220122   32.065607            0.0                 0.0       0
# 5      15.677426   42.492487            0.0                 0.0       0
#
#          xG
# 0  0.372237
# 1  0.062208
# 3  0.064829
# 4  0.050683
# 5  0.073719

# %% [markdown]
# # pickle models

# %%
import pickle

rf_pkl_filename = 'rfc.pkl'
rf_pkl = open(rf_pkl_filename, 'wb')
pickle.dump(random_forest_model, rf_pkl)
rf_pkl.close()

gb_pkl_filename = 'gb.pkl'
gb_pkl = open(gb_pkl_filename, 'wb')
pickle.dump(gradient_boost_model, gb_pkl)
gb_pkl.close()

xgb_pkl_filename = 'xgb.pkl'
xgb_pkl = open(xgb_pkl_filename, 'wb')
pickle.dump(xgboost_model, xgb_pkl)
xgb_pkl.close()

# %% [markdown]
# # Player Data
#
# - use the class **PlayerDataFrameCreator** to create dataframe of all players + relevant info + minutes

# %%
from player_cleaner import PlayerDataframeCreator

# %%
players = db.players.find()
games = db['games_update'].find()

# %%
pdc = PlayerDataframeCreator(games, players)

# %%
player_df = pdc.create_player_df()

# %%
player_df.head()
# Out:
#    minutes_played                 name  player_id  squad_num  team_id  \
# 0     1080.000000  Alexander Domínguez    19132.0       22.0       20
# 1      180.000000          Lucas Hoyos    27987.0       12.0       20
# 2      986.483333          Gastón Díaz    30896.0       24.0       20
# 3     1080.000000         Joaquín Laso    94225.0        6.0       20
# 4     1170.000000           Luis Abram    99779.0       29.0       20
#
#    position           birthday                                 club   foot  \
# 0    Goalie   Jun 5, 1987 (31)  Squad Club Atlético Vélez Sarsfield  right
# 1    Goalie  Apr 29, 1989 (29)  Squad Club Atlético Vélez Sarsfield  right
# 2  Defender  Mar 13, 1988 (30)  Squad Club Atlético Vélez Sarsfield  right
# 3  Defender   Jul 4, 1990 (28)  Squad Club Atlético Vélez Sarsfield  right
# 4  Defender  Feb 27, 1996 (22)  Squad Club Atlético Vélez Sarsfield   left
#
#    height  age  transfer_value(USD)
# 0  1,95 m   31                 2.01
# 1  1,83 m   29                 0.17
# 2  1,75 m   30                 0.57
# 3  1,85 m   28                 0.34
# 4  1,80 m   22                 0.51

# %% [markdown]
# # Merging
#
# combine the dataframe **total_df** (df with player id and xg stats) with **player_df** which
# has player metadata

# %%
from player_cleaner import FinalDataframe

# %%
fd = FinalDataframe(player_df, total_df)

# %%
final_df = fd.final_df_creator()

# %%
final_df.head()
# Out:
#      player_id                name    position  minutes_played  age  \
# 352    24256.0  Emmanuel Gigliotti     Forward     1247.966667   31
# 336      488.0      Lisandro López     Forward     1118.533333   35
# 417   119431.0        Matías Rojas  Midfielder      875.516667   23
# 125    98292.0     Facundo Barceló     Forward      688.916667   25
# 199   172801.0       Nahuel Bustos     Forward      857.900000   20
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA
# 352                 3.43     12      5.47      0.48         5.95
# 336                 2.01      8      3.07      0.35         3.42
# 417                 0.34      6      1.87      1.56         3.43
# 125                 0.57      5      2.59      0.24         2.83
# 199                 0.06      5      2.09      0.24         2.33

# %%
stats_df = fd.additional_stats()

# %%
stats_df.head()
# Out:
#      player_id                name    position  minutes_played  age  \
# 352    24256.0  Emmanuel Gigliotti     Forward     1247.966667   31
# 336      488.0      Lisandro López     Forward     1118.533333   35
# 417   119431.0        Matías Rojas  Midfielder      875.516667   23
# 125    98292.0     Facundo Barceló     Forward      688.916667   25
# 199   172801.0       Nahuel Bustos     Forward      857.900000   20
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 352                 3.43     12      5.47      0.48         5.95      0.43
# 336                 2.01      8      3.07      0.35         3.42      0.28
# 417                 0.34      6      1.87      1.56         3.43      0.35
# 125                 0.57      5      2.59      0.24         2.83      0.37
# 199                 0.06      5      2.09      0.24         2.33      0.24
#
#      Goals v. Expected Diff
# 352                    6.53
# 336                    4.93
# 417                    4.13
# 125                    2.41
# 199                    2.91

# %% [markdown]
# # Player Querying

# %%
#top 20 scorers
top_20_scorers = stats_df.head(20).copy()

# %%
top_20_xg = stats_df.sort_values('total_xG', ascending=False).head(20).copy()

# %%
top_20_scorers
# Out:
#      player_id                name    position  minutes_played  age  \
# 352    24256.0  Emmanuel Gigliotti     Forward     1247.966667   31
# 336      488.0      Lisandro López     Forward     1118.533333   35
# 417   119431.0        Matías Rojas  Midfielder      875.516667   23
# 125    98292.0     Facundo Barceló     Forward      688.916667   25
# 199   172801.0       Nahuel Bustos     Forward      857.900000   20
# 211   136659.0      Ángel González     Forward      913.783333   24
# 323    16081.0      Luis Rodríguez     Forward      917.900000   33
# 110    30266.0     Cristian Chávez     Forward     1088.266667   31
# 135   121814.0    Leonardo Heredia  Midfielder      845.866667   22
# 292    39578.0         Lucas Gamba     Forward      915.416667   31
# 55     55210.0      Nicolás Blandi     Forward      422.916667   28
# 41      8907.0   Federico González     Forward      744.900000   31
# 200   117606.0        Junior Arias     Forward      982.666667   25
# 212    31939.0     Santiago García     Forward     1159.566667   28
# 23    121341.0      Héctor Fértoli  Midfielder     1019.450000   24
# 240    20195.0     Sebastián Ribas     Forward     1166.283333   30
# 254   114108.0   Nicolás Fernández     Forward     1023.716667   22
# 317    85272.0    Rodrigo Aliendro  Midfielder     1026.716667   27
# 268    39414.0   Fernando Zampedri     Forward      966.066667   30
# 35     68605.0       Lucas Menossi  Midfielder     1098.883333   26
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 352                 3.43     12      5.47      0.48         5.95      0.43
# 336                 2.01      8      3.07      0.35         3.42      0.28
# 417                 0.34      6      1.87      1.56         3.43      0.35
# 125                 0.57      5      2.59      0.24         2.83      0.37
# 199                 0.06      5      2.09      0.24         2.33      0.24
# 211                 2.86      5      1.81      0.48         2.29      0.23
# 323                 1.71      4      2.75      0.73         3.48      0.34
# 110                 0.57      4      2.53      0.59         3.12      0.26
# 135                 0.06      4      1.21      0.15         1.36      0.14
# 292                 2.01      4      1.34      0.64         1.98      0.19
# 55                  6.29      4      2.14      0.52         2.66      0.57
# 41                  0.91      4      2.11      0.55         2.66      0.32
# 200                 2.29      4      2.28      0.67         2.95      0.27
# 212                 6.86      4      3.45      0.35         3.80      0.29
# 23                  0.80      4      2.39      0.84         3.23      0.29
# 240                 1.71      4      4.07      0.21         4.28      0.33
# 254                 3.43      4      2.92      0.31         3.23      0.28
# 317                 0.86      4      0.83      0.31         1.14      0.10
# 268                 3.43      4      3.38      0.00         3.38      0.31
# 35                  1.71      3      1.73      0.32         2.05      0.17
#
#      Goals v. Expected Diff
# 352                    6.53
# 336                    4.93
# 417                    4.13
# 125                    2.41
# 199                    2.91
# 211                    3.19
# 323                    1.25
# 110                    1.47
# 135                    2.79
# 292                    2.66
# 55                     1.86
# 41                     1.89
# 200                    1.72
# 212                    0.55
# 23                     1.61
# 240                   -0.07
# 254                    1.08
# 317                    3.17
# 268                    0.62
# 35                     1.27

# %%
top_20_xg.head()
# Out:
#      player_id                name position  minutes_played  age  \
# 352    24256.0  Emmanuel Gigliotti  Forward     1247.966667   31
# 240    20195.0     Sebastián Ribas  Forward     1166.283333   30
# 337    17217.0   Jonatan Cristaldo  Forward      944.966667   29
# 97     93853.0      Franco Soldano  Forward     1240.350000   24
# 212    31939.0     Santiago García  Forward     1159.566667   28
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 352                 3.43     12      5.47      0.48         5.95      0.43
# 240                 1.71      4      4.07      0.21         4.28      0.33
# 337                 1.37      3      3.85      0.35         4.20      0.40
# 97                  5.71      2      3.59      0.37         3.96      0.29
# 212                 6.86      4      3.45      0.35         3.80      0.29
#
#      Goals v. Expected Diff
# 352                    6.53
# 240                   -0.07
# 337                   -0.85
# 97                    -1.59
# 212                    0.55

# %%
top_20_contributions = stats_df.sort_values('total_xG+xA', ascending=False).head(20).copy()

# %%
top_20_contributions.head()
# Out:
#      player_id                 name    position  minutes_played  age  \
# 352    24256.0   Emmanuel Gigliotti     Forward     1247.966667   31
# 333    81286.0  Guillermo Fernández  Midfielder     1035.433333   27
# 24     36681.0      Víctor Figueroa  Midfielder      794.483333   35
# 240    20195.0      Sebastián Ribas     Forward     1166.283333   30
# 337    17217.0    Jonatan Cristaldo     Forward      944.966667   29
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 352                 3.43     12      5.47      0.48         5.95      0.43
# 333                 4.57      3      1.76      2.96         4.72      0.41
# 24                  0.23      0      1.99      2.52         4.51      0.51
# 240                 1.71      4      4.07      0.21         4.28      0.33
# 337                 1.37      3      3.85      0.35         4.20      0.40
#
#      Goals v. Expected Diff
# 352                    6.53
# 333                    1.24
# 24                    -1.99
# 240                   -0.07
# 337                   -0.85

# %%
stats_df[stats_df['name'] == 'Gonzalo Martínez']
# Out:
#      player_id              name    position  minutes_played  age  \
# 303    77919.0  Gonzalo Martínez  Midfielder           321.7   25
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 303                17.14      1      0.48       0.0         0.48      0.13
#
#      Goals v. Expected Diff
# 303                    0.52

# %%
top_20_per90 = stats_df[(stats_df['minutes_played'] > 500) & (stats_df['age'] < 26)].sort_values('xG+xA/90', ascending=False).head(20).copy()

# %%
top_20_per90
# Out:
#      player_id                    name    position  minutes_played  age  \
# 170   118855.0          Nazareno Solís     Forward      597.050000   24
# 5     185745.0         Lucas Robertone  Midfielder      965.516667   21
# 320   103537.0           David Barbona  Midfielder      624.300000   23
# 125    98292.0         Facundo Barceló     Forward      688.916667   25
# 79    189736.0     Alexis Mac Allister  Midfielder      533.833333   19
# 417   119431.0            Matías Rojas  Midfielder      875.516667   23
# 180    43746.0           Edwin Cardona  Midfielder      676.033333   25
# 54    172565.0         Nicolás Reniero     Forward     1057.333333   23
# 84    209887.0            Gastón Verón     Forward      577.350000   17
# 249   193188.0            Gastón Togni  Midfielder     1115.333333   21
# 97     93853.0          Franco Soldano     Forward     1240.350000   24
# 23    121341.0          Héctor Fértoli  Midfielder     1019.450000   24
# 254   114108.0       Nicolás Fernández     Forward     1023.716667   22
# 43     85349.0  Juan Ignacio Cavallaro     Forward      515.983333   24
# 338    87323.0       Ricardo Centurión     Forward      787.350000   25
# 200   117606.0            Junior Arias     Forward      982.666667   25
# 148   185878.0           Juan Brunetta  Midfielder      736.433333   21
# 182   111421.0          Cristian Pavón     Forward      553.933333   22
# 393   204671.0         Tomás Chancalay  Midfielder      634.850000   19
# 199   172801.0           Nahuel Bustos     Forward      857.900000   20
#
#      transfer_value(USD)  goals  total_xG  total_xA  total_xG+xA  xG+xA/90  \
# 170                 0.69      1      1.39      2.09         3.48      0.52
# 5                   3.43      3      2.40      1.76         4.16      0.39
# 320                 2.29      2      1.65      0.95         2.60      0.37
# 125                 0.57      5      2.59      0.24         2.83      0.37
# 79                  4.57      2      1.27      0.88         2.15      0.36
# 417                 0.34      6      1.87      1.56         3.43      0.35
# 180                 6.29      2      1.02      1.55         2.57      0.34
# 54                  2.29      3      2.94      0.79         3.73      0.32
# 84                   NaN      1      1.86      0.16         2.02      0.31
# 249                 0.17      3      2.70      0.85         3.55      0.29
# 97                  5.71      2      3.59      0.37         3.96      0.29
# 23                  0.80      4      2.39      0.84         3.23      0.29
# 254                 3.43      4      2.92      0.31         3.23      0.28
# 43                  1.44      2      1.11      0.52         1.63      0.28
# 338                 5.71      2      1.91      0.42         2.33      0.27
# 200                 2.29      4      2.28      0.67         2.95      0.27
# 148                 1.44      1      1.48      0.76         2.24      0.27
# 182                22.86      2      1.14      0.54         1.68      0.27
# 393                 3.15      2      0.81      0.88         1.69      0.24
# 199                 0.06      5      2.09      0.24         2.33      0.24
#
#      Goals v. Expected Diff
# 170                   -0.39
# 5                      0.60
# 320                    0.35
# 125                    2.41
# 79                     0.73
# 417                    4.13
# 180                    0.98
# 54                     0.06
# 84                    -0.86
# 249                    0.30
# 97                    -1.59
# 23                     1.61
# 254                    1.08
# 43                     0.89
# 338                    0.09
# 200                    1.72
# 148                   -0.48
# 182                    0.86
# 393                    1.19
# 199                    2.91

# %%
from analysis import individual_shot_map, plot_goals_map

# %%
individual_shot_map(df_no_pen, final_df, 20195.0)

# %%
individual_shot_map(df_no_pen, final_df, 121814.0)

# %%
for player_id in list(top_20_per90['player_id']):
    individual_shot_map(df_no_pen, final_df, player_id)

# %%
lowest_goal_prob = df_no_pen[(df_no_pen['is_goal'] == 1)].sort_values('xG').head(20)

# %%
lowest_goal_prob['xG'].mean()
# Out:
# 0.062059963980513264

# %%
plot_goals_map(lowest_goal_prob, 0.060 )

# %%
highest_goal_prob = df_no_pen[(df_no_pen['is_goal'] == 1)].sort_values('xG', ascending=False).head(20)

# %%
highest_goal_prob['xG'].mean()
# Out:
# 0.41949748979175994

# %%
plot_goals_map(highest_goal_prob, 0.42 )

# %% [markdown]
# # Takeaways:
#
# When only accounting for shots that are not penalty kick attempts:
#
# - actual goals scored: 342 vs. number of predicted goals: 342
#
# - highest probability it will award a shot is ~.40. that seems low
#
# - half the players in the top 20 of goals are also in the top 20 of xG
#
# ## Limitations:
#
# - unable to filter out header/weak foot/free kick attempts

# %%
top_20_name = set(top_20_scorers.name)
top_20_xg_name = set(top_20_xg.name)

# %%
list(set.intersection(top_20_name, top_20_xg_name))
# Out:
# ['Fernando Zampedri',
#  'Cristian Chávez',
#  'Lisandro López',
#  'Luis Rodríguez',
#  'Emmanuel Gigliotti',
#  'Sebastián Ribas',
#  'Facundo Barceló',
#  'Nicolás Fernández',
#  'Héctor Fértoli',
#  'Santiago García']

# %% [markdown]
# # Next Steps:
#
# - see how model predicts the rest of the season
#
# - add a position or player variable to model
