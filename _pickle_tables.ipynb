# %%
from combined_player import player_minutes_value
from html_scraper import db
from mongo_to_db import create_master_df

# %%
import pprint
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # Dataframe of Players

# %%
games = db.games.find()
players = db.players.find()

# %%
final_df = player_minutes_value(games, players)

# %%
final_df.head()
# Out:
#    player_id          player_name                                 club  \
# 0    19132.0  Alexander Domínguez  Squad Club Atlético Vélez Sarsfield
# 1    27987.0          Lucas Hoyos  Squad Club Atlético Vélez Sarsfield
# 2    30896.0          Gastón Díaz  Squad Club Atlético Vélez Sarsfield
# 3    94225.0         Joaquín Laso  Squad Club Atlético Vélez Sarsfield
# 4    99779.0           Luis Abram  Squad Club Atlético Vélez Sarsfield
#
#             birthday  age   foot  squad_num  height  total_minutes_played  \
# 0   Jun 5, 1987 (31)   31  right       22.0  1,95 m           1080.000000
# 1  Apr 29, 1989 (29)   29  right       12.0  1,83 m             90.000000
# 2  Mar 13, 1988 (30)   30  right       24.0  1,75 m            896.483333
# 3   Jul 4, 1990 (28)   28  right        6.0  1,85 m            990.000000
# 4  Feb 27, 1996 (22)   22   left       29.0  1,80 m           1080.000000
#
#   transfer_value(sterlings)  transfer_value(USD)
# 0                    £1.58m                 2.01
# 1                     £135k                 0.17
# 2                     £450k                 0.57
# 3                     £270k                 0.34
# 4                     £405k                 0.51

# %% [markdown]
# # Dataframe of Shots

# %%
games = db.games.find()
shots_df = create_master_df(games)
# Out:
# /Users/david/galvanize/super_liga_xg/mongo_to_db.py:69: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   final_df = pd.concat([attach_to_df, df], axis=0, ignore_index=True)
# /Users/david/galvanize/super_liga_xg/dataframe_cleaner.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   input_df['is_goal'] = input_df.loc[:, 'shot_type'].isin([9, 11, 12, 13]).astype(int)

# %%
shots_df.head()
# Out:
#   game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0  448548    99779.0           6.67           0.00           1.51
# 1  448548    60730.0          21.33          12.00           4.24
# 2  448548   177285.0          12.00           1.78           0.00
# 3  448548   185745.0           8.44           0.89          14.53
# 4  448548    77892.0          22.22           0.44          13.92
#
#    shot_coord_y2 shot_coord_z1  shot_coord_z2   shot_id shot_type team_id  \
# 0          -1.21            -1           0.83  22336297        11      20
# 1          -0.91            -1           0.73  22336386        35      20
# 2          -3.03            -1           0.21  22336583        13      20
# 3          -6.66            -1          -1.00  22336723        33      20
# 4          -8.48            -1          -1.00  22336739        33      13
#
#    time_of_event(min)  passed_from_id  pass_coord_x1  pass_coord_x2  \
# 0            1.033333        177285.0           0.89          12.44
# 1            9.683333             NaN            NaN            NaN
# 2           26.833333             NaN            NaN            NaN
# 3           38.883333        177285.0          22.67           6.22
# 4           40.083333             NaN            NaN            NaN
#
#    pass_coord_y1  pass_coord_y2  pass_coord_z1  pass_coord_z2  corner_kick  \
# 0          29.36          -4.84           -1.0           -1.0          1.0
# 1            NaN            NaN            NaN            NaN          0.0
# 2            NaN            NaN            NaN            NaN          0.0
# 3           3.93          19.67           -1.0           -1.0          0.0
# 4            NaN            NaN            NaN            NaN          0.0
#
#    shot_distance  shot_angle assisted_shot is_penalty_attempt  is_goal
# 0       6.838786   12.755990             1                  0      1.0
# 1      21.747333   11.242763             0                  0      0.0
# 2      12.000000    0.000000             0                  1      1.0
# 3      16.803407   59.849102             1                  0      0.0
# 4      26.220122   32.065607             0                  0      0.0

# %% [markdown]
# # Get Whole Dataframe Ready for Predictions

# %%
from model_prep import create_rf_prep, create_xG_df, create_summed_xG_df

# %%
model_ready_df = create_rf_prep(shots_df)

# %%
model_ready_df.head()
# Out:
#    player_id  shot_distance  shot_angle  assisted_shot  is_penalty_attempt
# 0    99779.0       6.838786   12.755990            1.0                 0.0
# 1    60730.0      21.747333   11.242763            0.0                 0.0
# 2   177285.0      12.000000    0.000000            0.0                 1.0
# 3   185745.0      16.803407   59.849102            1.0                 0.0
# 4    77892.0      26.220122   32.065607            0.0                 0.0

# %% [markdown]
# # Grab pickl'd models

# %%
import pickle

# %%
rf_model = pickle.load(open("rfc.pkl", "rb"))
gb_model = pickle.load(open("gb.pkl", "rb"))
xgb_model = pickle.load(open("xgb.pkl", "rb"))

# %%
columns = ['shot_distance', 'shot_angle', 'assisted_shot', 'is_penalty_attempt']

# %%
p_random_forest = rf_model.predict_proba(model_ready_df[columns])
p_gradient_boost =  gb_model.predict_proba(model_ready_df[columns])
p_xgboost = xgb_model.predict_proba(model_ready_df[columns])
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished

# %%
p_ensemble = (p_random_forest + p_gradient_boost + p_xgboost) / 3
# Out:
# array([[0.64167905, 0.35832094],
#        [0.9258825 , 0.07411751],
#        [0.25544291, 0.74455709],
#        ...,
#        [0.93637081, 0.0636292 ],
#        [0.90362276, 0.09637724],
#        [0.93865846, 0.06134154]])

# %%
rf_xg = create_xG_df(model_ready_df, shots_df['is_goal'], p_random_forest)
rf_contributions = create_summed_xG_df(rf_xg)

gb_xg = create_xG_df(model_ready_df, shots_df['is_goal'], p_gradient_boost)
gb_contributions = create_summed_xG_df(gb_xg)

xgb_xg = create_xG_df(model_ready_df, shots_df['is_goal'], p_xgboost)
xgb_contributions = create_summed_xG_df(xgb_xg)

ensemble_xg = create_xG_df(model_ready_df, shots_df['is_goal'], p_ensemble)
ensemble_contributions = create_summed_xG_df(ensemble_xg)

# %%
rf_contributions.head()
# Out:
#    player_id  total_xG  total_xA  total_xG+xA  goals
# 0    24256.0      5.03      2.32         7.35   12.0
# 1      488.0      4.86      1.08         5.94    9.0
# 2    16081.0      4.60      1.37         5.97    7.0
# 3      101.0      4.37      0.93         5.30    5.0
# 4    93853.0      3.68      1.99         5.67    2.0

# %%
gb_contributions.head()
# Out:
#    player_id  total_xG  total_xA  total_xG+xA  goals
# 0    24256.0      5.78      2.55         8.33   12.0
# 1      101.0      4.45      0.94         5.39    5.0
# 2      488.0      4.43      0.78         5.21    9.0
# 3    16081.0      3.95      1.16         5.11    7.0
# 4    17217.0      3.77      0.84         4.61    3.0

# %%
xgb_contributions.head()
# Out:
#    player_id  total_xG  total_xA  total_xG+xA  goals
# 0    24256.0      6.24      2.84         9.08   12.0
# 1      488.0      5.26      1.27         6.53    9.0
# 2    16081.0      5.01      1.55         6.56    7.0
# 3      101.0      4.73      1.17         5.90    5.0
# 4    93853.0      4.25      2.27         6.52    2.0

# %%
ensemble_contributions.head()
# Out:
#    player_id  total_xG  total_xA  total_xG+xA  goals
# 0    24256.0      5.68      2.57         8.25   12.0
# 1      488.0      4.85      1.05         5.90    9.0
# 2    16081.0      4.52      1.36         5.88    7.0
# 3      101.0      4.52      1.01         5.53    5.0
# 4    17217.0      3.80      0.97         4.77    3.0

# %% [markdown]
# # Merge with final_df (player info)

# %%
rf_sl = pd.merge(rf_contributions, final_df, on=['player_id'])
gb_sl = pd.merge(gb_contributions, final_df, on=['player_id'])
xgb_sl = pd.merge(xgb_contributions, final_df, on=['player_id'])
ens_sl = pd.merge(ensemble_contributions, final_df, on=['player_id'])

# %%
rf_sl['xG+xA/90'] = rf_sl['total_xG+xA'] / (rf_sl['total_minutes_played'] / 90 )
gb_sl['xG+xA/90'] = gb_sl['total_xG+xA'] / (gb_sl['total_minutes_played'] / 90 )
xgb_sl['xG+xA/90'] = xgb_sl['total_xG+xA'] / (xgb_sl['total_minutes_played'] / 90 )
ens_sl['xG+xA/90'] = ens_sl['total_xG+xA'] / (ens_sl['total_minutes_played'] / 90 )

# %%
final_col = ['player_id', 'player_name', 'club', 'birthday', 'age', 'foot', 'squad_num',
       'total_xG', 'total_xA', 'total_xG+xA', 'goals', 'xG+xA/90', 'transfer_value(USD)', 'total_minutes_played']

# %%
rf_sl_final = rf_sl[final_col]
gb_sl_final = gb_sl[final_col]
xgb_sl_final = xgb_sl[final_col]
ens_sl_final = ens_sl[final_col]

# %% [markdown]
# ### final dataframes

# %%
rf_sl_final.head()
# Out:
#    player_id         player_name                                  club  \
# 0    24256.0  Emmanuel Gigliotti     Squad Club Atlético Independiente
# 1      488.0      Lisandro López                     Squad Racing Club
# 2    16081.0      Luis Rodríguez           Squad Club Atlético Tucumán
# 3      101.0     Darío Cvitanich          Squad Club Atlético Banfield
# 4    93853.0      Franco Soldano  Squad Club Atlético Unión (Santa Fe)
#
#             birthday  age   foot  squad_num  total_xG  total_xA  total_xG+xA  \
# 0  May 20, 1987 (31)   31  right        9.0      5.03      2.32         7.35
# 1   Mar 2, 1983 (35)   35  right       15.0      4.86      1.08         5.94
# 2   Jan 1, 1985 (33)   33  right        7.0      4.60      1.37         5.97
# 3  May 16, 1984 (34)   34  right       20.0      4.37      0.93         5.30
# 4  Sep 14, 1994 (24)   24  right       27.0      3.68      1.99         5.67
#
#    goals  xG+xA/90  transfer_value(USD)  total_minutes_played
# 0   12.0  0.676403                 3.43            977.966667
# 1    9.0  0.570260                 2.01            937.466667
# 2    7.0  0.648991                 1.71            827.900000
# 3    5.0  0.492218                 1.71            969.083333
# 4    2.0  0.481256                 5.71           1060.350000

# %%
gb_sl_final.head()
# Out:
#    player_id         player_name                               club  \
# 0    24256.0  Emmanuel Gigliotti  Squad Club Atlético Independiente
# 1      101.0     Darío Cvitanich       Squad Club Atlético Banfield
# 2      488.0      Lisandro López                  Squad Racing Club
# 3    16081.0      Luis Rodríguez        Squad Club Atlético Tucumán
# 4    17217.0   Jonatan Cristaldo                  Squad Racing Club
#
#             birthday  age   foot  squad_num  total_xG  total_xA  total_xG+xA  \
# 0  May 20, 1987 (31)   31  right        9.0      5.78      2.55         8.33
# 1  May 16, 1984 (34)   34  right       20.0      4.45      0.94         5.39
# 2   Mar 2, 1983 (35)   35  right       15.0      4.43      0.78         5.21
# 3   Jan 1, 1985 (33)   33  right        7.0      3.95      1.16         5.11
# 4   Mar 5, 1989 (29)   29  right        9.0      3.77      0.84         4.61
#
#    goals  xG+xA/90  transfer_value(USD)  total_minutes_played
# 0   12.0  0.766591                 3.43            977.966667
# 1    5.0  0.500576                 1.71            969.083333
# 2    9.0  0.500178                 2.01            937.466667
# 3    7.0  0.555502                 1.71            827.900000
# 4    3.0  0.530303                 1.37            782.383333

# %%
xgb_sl_final.head()
# Out:
#    player_id         player_name                                  club  \
# 0    24256.0  Emmanuel Gigliotti     Squad Club Atlético Independiente
# 1      488.0      Lisandro López                     Squad Racing Club
# 2    16081.0      Luis Rodríguez           Squad Club Atlético Tucumán
# 3      101.0     Darío Cvitanich          Squad Club Atlético Banfield
# 4    93853.0      Franco Soldano  Squad Club Atlético Unión (Santa Fe)
#
#             birthday  age   foot  squad_num  total_xG  total_xA  total_xG+xA  \
# 0  May 20, 1987 (31)   31  right        9.0      6.24      2.84         9.08
# 1   Mar 2, 1983 (35)   35  right       15.0      5.26      1.27         6.53
# 2   Jan 1, 1985 (33)   33  right        7.0      5.01      1.55         6.56
# 3  May 16, 1984 (34)   34  right       20.0      4.73      1.17         5.90
# 4  Sep 14, 1994 (24)   24  right       27.0      4.25      2.27         6.52
#
#    goals  xG+xA/90  transfer_value(USD)  total_minutes_played
# 0   12.0  0.835611                 3.43            977.966667
# 1    9.0  0.626902                 2.01            937.466667
# 2    7.0  0.713130                 1.71            827.900000
# 3    5.0  0.547940                 1.71            969.083333
# 4    2.0  0.553402                 5.71           1060.350000

# %%
ens_sl_final.head()
# Out:
#    player_id         player_name                               club  \
# 0    24256.0  Emmanuel Gigliotti  Squad Club Atlético Independiente
# 1      488.0      Lisandro López                  Squad Racing Club
# 2    16081.0      Luis Rodríguez        Squad Club Atlético Tucumán
# 3      101.0     Darío Cvitanich       Squad Club Atlético Banfield
# 4    17217.0   Jonatan Cristaldo                  Squad Racing Club
#
#             birthday  age   foot  squad_num  total_xG  total_xA  total_xG+xA  \
# 0  May 20, 1987 (31)   31  right        9.0      5.68      2.57         8.25
# 1   Mar 2, 1983 (35)   35  right       15.0      4.85      1.05         5.90
# 2   Jan 1, 1985 (33)   33  right        7.0      4.52      1.36         5.88
# 3  May 16, 1984 (34)   34  right       20.0      4.52      1.01         5.53
# 4   Mar 5, 1989 (29)   29  right        9.0      3.80      0.97         4.77
#
#    goals  xG+xA/90  transfer_value(USD)  total_minutes_played
# 0   12.0  0.759228                 3.43            977.966667
# 1    9.0  0.566420                 2.01            937.466667
# 2    7.0  0.639208                 1.71            827.900000
# 3    5.0  0.513578                 1.71            969.083333
# 4    3.0  0.548708                 1.37            782.383333

# %% [markdown]
# ### players younger than 25, with an xG+xA contribution of over 0.3 per game, who have played at least 300 minutes

# %%
# random forest
rf_sl_final[(rf_sl_final['age'] < 25) & (rf_sl_final['xG+xA/90'] > 0.3) & (rf_sl_final['transfer_value(USD)'] < 5) & (rf_sl_final['total_minutes_played'] > 300)]
# Out:
#      player_id           player_name  \
# 5     135386.0     Leonardo Sequeira
# 15    172565.0       Nicolás Reniero
# 19    193188.0          Gastón Togni
# 20    114108.0     Nicolás Fernández
# 29    185745.0       Lucas Robertone
# 41    172801.0         Nahuel Bustos
# 47    118855.0        Nazareno Solís
# 50    172730.0    Nicolás Leguizamón
# 53     95766.0         Adrián Balboa
# 56    175369.0      Franco Troyansky
# 64    131511.0  Francisco Illarregui
# 74    122082.0      Franco Cristaldo
# 98    189736.0   Alexis Mac Allister
# 106   123767.0        Victorio Ramis
#
#                                                  club           birthday  age  \
# 5                        Squad Club Atlético Belgrano  Apr 26, 1995 (23)   23
# 15         Squad Club Atlético San Lorenzo de Almagro  Mar 18, 1995 (23)   23
# 19   Squad Club Social y Deportivo Defensa y Justicia  Sep 20, 1997 (21)   21
# 20   Squad Club Social y Deportivo Defensa y Justicia   Feb 8, 1996 (22)   22
# 29                Squad Club Atlético Vélez Sarsfield  Mar 18, 1997 (21)   21
# 41                       Squad Club Atlético Talleres   Jul 4, 1998 (20)   20
# 47                Squad Club Atlético San Martín (SJ)  Apr 22, 1994 (24)   24
# 50                          Squad Club Atlético Colón  Jan 26, 1995 (23)   23
# 53                       Squad Club Atlético Belgrano  Jan 19, 1994 (24)   24
# 56               Squad Club Atlético Unión (Santa Fe)   Jun 3, 1997 (21)   21
# 64       Squad Asociación Atlética Argentinos Juniors   May 6, 1997 (21)   21
# 74                Squad Club Atlético San Martín (SJ)  Aug 15, 1996 (22)   22
# 98       Squad Asociación Atlética Argentinos Juniors  Dec 24, 1998 (19)   19
# 106     Squad Club Deportivo Godoy Cruz Antonio Tomba   Jul 7, 1994 (24)   24
#
#       foot  squad_num  total_xG  total_xA  total_xG+xA  goals  xG+xA/90  \
# 5    right       26.0      3.59      0.32         3.91    2.0  0.386328
# 15   right       15.0      2.81      1.90         4.71    3.0  0.483169
# 19    left        7.0      2.47      0.64         3.11    2.0  0.328972
# 20   right       29.0      2.38      1.40         3.78    3.0  0.451363
# 29   right       16.0      2.04      0.99         3.03    2.0  0.309359
# 41   right        7.0      1.84      0.66         2.50    4.0  0.325670
# 47    left        7.0      1.68      0.45         2.13    1.0  0.321079
# 50   right        9.0      1.61      1.16         2.77    0.0  0.593265
# 53   right       11.0      1.53      0.95         2.48    1.0  0.368530
# 56    left       22.0      1.51      1.17         2.68    1.0  0.408410
# 64       -       27.0      1.36      0.93         2.29    1.0  0.533247
# 74   right       32.0      1.20      1.00         2.20    0.0  0.402425
# 98   right       10.0      1.02      0.61         1.63    1.0  0.319550
# 106  right       11.0      0.98      0.44         1.42    0.0  0.301593
#
#      transfer_value(USD)  total_minutes_played
# 5                   1.71            910.883333
# 15                  2.29            877.333333
# 19                  0.17            850.833333
# 20                  3.43            753.716667
# 29                  3.43            881.500000
# 41                  0.06            690.883333
# 47                  0.69            597.050000
# 50                  1.71            420.216667
# 53                  0.86            605.650000
# 56                  1.44            590.583333
# 64                  0.17            386.500000
# 74                  0.46            492.016667
# 98                  4.57            459.083333
# 106                 3.15            423.750000

# %%
#gradient boost
gb_sl_final[(gb_sl_final['age'] < 25) & (gb_sl_final['xG+xA/90'] > 0.3) & (gb_sl_final['transfer_value(USD)'] < 5) & (gb_sl_final['total_minutes_played'] > 300)]
# Out:
#     player_id           player_name  \
# 7    135386.0     Leonardo Sequeira
# 14   172565.0       Nicolás Reniero
# 15   193188.0          Gastón Togni
# 16   114108.0     Nicolás Fernández
# 27   163041.0     Alexander Barboza
# 30   172801.0         Nahuel Bustos
# 38   118855.0        Nazareno Solís
# 40   172730.0    Nicolás Leguizamón
# 50    95766.0         Adrián Balboa
# 58   175369.0      Franco Troyansky
# 67   131511.0  Francisco Illarregui
# 79   123767.0        Victorio Ramis
# 88   189736.0   Alexis Mac Allister
# 93   122082.0      Franco Cristaldo
#
#                                                 club           birthday  age  \
# 7                       Squad Club Atlético Belgrano  Apr 26, 1995 (23)   23
# 14        Squad Club Atlético San Lorenzo de Almagro  Mar 18, 1995 (23)   23
# 15  Squad Club Social y Deportivo Defensa y Justicia  Sep 20, 1997 (21)   21
# 16  Squad Club Social y Deportivo Defensa y Justicia   Feb 8, 1996 (22)   22
# 27  Squad Club Social y Deportivo Defensa y Justicia  Mar 16, 1995 (23)   23
# 30                      Squad Club Atlético Talleres   Jul 4, 1998 (20)   20
# 38               Squad Club Atlético San Martín (SJ)  Apr 22, 1994 (24)   24
# 40                         Squad Club Atlético Colón  Jan 26, 1995 (23)   23
# 50                      Squad Club Atlético Belgrano  Jan 19, 1994 (24)   24
# 58              Squad Club Atlético Unión (Santa Fe)   Jun 3, 1997 (21)   21
# 67      Squad Asociación Atlética Argentinos Juniors   May 6, 1997 (21)   21
# 79     Squad Club Deportivo Godoy Cruz Antonio Tomba   Jul 7, 1994 (24)   24
# 88      Squad Asociación Atlética Argentinos Juniors  Dec 24, 1998 (19)   19
# 93               Squad Club Atlético San Martín (SJ)  Aug 15, 1996 (22)   22
#
#      foot  squad_num  total_xG  total_xA  total_xG+xA  goals  xG+xA/90  \
# 7   right       26.0      3.20      0.26         3.46    2.0  0.341866
# 14  right       15.0      2.69      1.83         4.52    3.0  0.463678
# 15   left        7.0      2.65      0.61         3.26    2.0  0.344838
# 16  right       29.0      2.53      1.47         4.00    3.0  0.477633
# 27   left        6.0      2.06      0.99         3.05    1.0  0.321272
# 30  right        7.0      1.98      0.67         2.65    4.0  0.345210
# 38   left        7.0      1.84      0.41         2.25    1.0  0.339168
# 40  right        9.0      1.73      1.24         2.97    0.0  0.636100
# 50  right       11.0      1.60      0.99         2.59    1.0  0.384876
# 58   left       22.0      1.41      1.08         2.49    1.0  0.379455
# 67      -       27.0      1.30      0.90         2.20    1.0  0.512290
# 79  right       11.0      1.19      0.55         1.74    0.0  0.369558
# 88  right       10.0      1.07      0.71         1.78    1.0  0.348956
# 93  right       32.0      1.05      0.87         1.92    0.0  0.351208
#
#     transfer_value(USD)  total_minutes_played
# 7                  1.71            910.883333
# 14                 2.29            877.333333
# 15                 0.17            850.833333
# 16                 3.43            753.716667
# 27                 2.86            854.416667
# 30                 0.06            690.883333
# 38                 0.69            597.050000
# 40                 1.71            420.216667
# 50                 0.86            605.650000
# 58                 1.44            590.583333
# 67                 0.17            386.500000
# 79                 3.15            423.750000
# 88                 4.57            459.083333
# 93                 0.46            492.016667

# %%
#xgboost
yp_xgb = xgb_sl_final[(xgb_sl_final['age'] < 25) & (xgb_sl_final['xG+xA/90'] > 0.3) & (xgb_sl_final['transfer_value(USD)'] < 5) & (xgb_sl_final['total_minutes_played'] > 300)].copy()
xgb_sl_final[(xgb_sl_final['age'] < 25) & (xgb_sl_final['xG+xA/90'] > 0.3) & (xgb_sl_final['transfer_value(USD)'] < 5) & (xgb_sl_final['total_minutes_played'] > 300)]
# Out:
#      player_id           player_name  \
# 10    135386.0     Leonardo Sequeira
# 14    172565.0       Nicolás Reniero
# 17    114108.0     Nicolás Fernández
# 19    193188.0          Gastón Togni
# 24    121341.0        Héctor Fértoli
# 27    185745.0       Lucas Robertone
# 32    163041.0     Alexander Barboza
# 39    172801.0         Nahuel Bustos
# 44    118855.0        Nazareno Solís
# 47     95766.0         Adrián Balboa
# 48    172730.0    Nicolás Leguizamón
# 50    131511.0  Francisco Illarregui
# 54    175369.0      Franco Troyansky
# 55    186085.0        Matías Zaracho
# 60    185878.0         Juan Brunetta
# 61    103537.0         David Barbona
# 78    122082.0      Franco Cristaldo
# 84    189736.0   Alexis Mac Allister
# 94    123767.0        Victorio Ramis
# 149    87415.0         Marcelo Ortiz
#
#                                                  club           birthday  age  \
# 10                       Squad Club Atlético Belgrano  Apr 26, 1995 (23)   23
# 14         Squad Club Atlético San Lorenzo de Almagro  Mar 18, 1995 (23)   23
# 17   Squad Club Social y Deportivo Defensa y Justicia   Feb 8, 1996 (22)   22
# 19   Squad Club Social y Deportivo Defensa y Justicia  Sep 20, 1997 (21)   21
# 24              Squad Club Atlético Newell's Old Boys   Dec 3, 1994 (24)   24
# 27                Squad Club Atlético Vélez Sarsfield  Mar 18, 1997 (21)   21
# 32   Squad Club Social y Deportivo Defensa y Justicia  Mar 16, 1995 (23)   23
# 39                       Squad Club Atlético Talleres   Jul 4, 1998 (20)   20
# 44                Squad Club Atlético San Martín (SJ)  Apr 22, 1994 (24)   24
# 47                       Squad Club Atlético Belgrano  Jan 19, 1994 (24)   24
# 48                          Squad Club Atlético Colón  Jan 26, 1995 (23)   23
# 50       Squad Asociación Atlética Argentinos Juniors   May 6, 1997 (21)   21
# 54               Squad Club Atlético Unión (Santa Fe)   Jun 3, 1997 (21)   21
# 55                                  Squad Racing Club  Mar 10, 1998 (20)   20
# 60                       Squad Club Atlético Belgrano  May 12, 1997 (21)   21
# 61                        Squad Club Atlético Tucumán  Feb 22, 1995 (23)   23
# 78                Squad Club Atlético San Martín (SJ)  Aug 15, 1996 (22)   22
# 84       Squad Asociación Atlética Argentinos Juniors  Dec 24, 1998 (19)   19
# 94      Squad Club Deportivo Godoy Cruz Antonio Tomba   Jul 7, 1994 (24)   24
# 149               Squad Club Atlético Rosario Central  Jan 13, 1994 (24)   24
#
#       foot  squad_num  total_xG  total_xA  total_xG+xA  goals  xG+xA/90  \
# 10   right       26.0      3.79      0.36         4.15    2.0  0.410042
# 14   right       15.0      3.36      2.31         5.67    3.0  0.581649
# 17   right       29.0      2.95      1.73         4.68    3.0  0.558831
# 19    left        7.0      2.83      0.73         3.56    2.0  0.376572
# 24   right       26.0      2.51      0.87         3.38    3.0  0.355734
# 27   right       16.0      2.40      1.10         3.50    2.0  0.357345
# 32    left        6.0      2.30      1.01         3.31    1.0  0.348659
# 39   right        7.0      2.18      0.83         3.01    4.0  0.392107
# 44    left        7.0      2.07      0.56         2.63    1.0  0.396449
# 47   right       11.0      1.99      1.18         3.17    1.0  0.471064
# 48   right        9.0      1.96      1.45         3.41    0.0  0.730338
# 50       -       27.0      1.90      1.35         3.25    1.0  0.756792
# 54    left       22.0      1.84      1.40         3.24    1.0  0.493749
# 55   right       28.0      1.82      0.93         2.75    0.0  0.349617
# 60    left       17.0      1.70      0.76         2.46    1.0  0.305893
# 61   right       19.0      1.69      0.50         2.19    1.0  0.349530
# 78   right       32.0      1.38      1.10         2.48    0.0  0.453643
# 84   right       10.0      1.33      0.84         2.17    1.0  0.425413
# 94   right       11.0      1.27      0.55         1.82    0.0  0.386549
# 149  right        6.0      0.89      0.77         1.66    0.0  0.332000
#
#      transfer_value(USD)  total_minutes_played
# 10                  1.71            910.883333
# 14                  2.29            877.333333
# 17                  3.43            753.716667
# 19                  0.17            850.833333
# 24                  0.80            855.133333
# 27                  3.43            881.500000
# 32                  2.86            854.416667
# 39                  0.06            690.883333
# 44                  0.69            597.050000
# 47                  0.86            605.650000
# 48                  1.71            420.216667
# 50                  0.17            386.500000
# 54                  1.44            590.583333
# 55                  4.00            707.916667
# 60                  1.44            723.783333
# 61                  2.29            563.900000
# 78                  0.46            492.016667
# 84                  4.57            459.083333
# 94                  3.15            423.750000
# 149                 0.06            450.000000

# %%
ens_sl_final[(ens_sl_final['age'] < 25) & (ens_sl_final['xG+xA/90'] > 0.3) & (ens_sl_final['transfer_value(USD)'] < 5) & (ens_sl_final['total_minutes_played'] > 300)]
# Out:
#     player_id           player_name  \
# 7    135386.0     Leonardo Sequeira
# 14   172565.0       Nicolás Reniero
# 17   193188.0          Gastón Togni
# 18   114108.0     Nicolás Fernández
# 26   121341.0        Héctor Fértoli
# 28   185745.0       Lucas Robertone
# 30   163041.0     Alexander Barboza
# 39   172801.0         Nahuel Bustos
# 44   118855.0        Nazareno Solís
# 46   172730.0    Nicolás Leguizamón
# 49    95766.0         Adrián Balboa
# 56   175369.0      Franco Troyansky
# 58   131511.0  Francisco Illarregui
# 83   122082.0      Franco Cristaldo
# 88   123767.0        Victorio Ramis
# 89   189736.0   Alexis Mac Allister
#
#                                                 club           birthday  age  \
# 7                       Squad Club Atlético Belgrano  Apr 26, 1995 (23)   23
# 14        Squad Club Atlético San Lorenzo de Almagro  Mar 18, 1995 (23)   23
# 17  Squad Club Social y Deportivo Defensa y Justicia  Sep 20, 1997 (21)   21
# 18  Squad Club Social y Deportivo Defensa y Justicia   Feb 8, 1996 (22)   22
# 26             Squad Club Atlético Newell's Old Boys   Dec 3, 1994 (24)   24
# 28               Squad Club Atlético Vélez Sarsfield  Mar 18, 1997 (21)   21
# 30  Squad Club Social y Deportivo Defensa y Justicia  Mar 16, 1995 (23)   23
# 39                      Squad Club Atlético Talleres   Jul 4, 1998 (20)   20
# 44               Squad Club Atlético San Martín (SJ)  Apr 22, 1994 (24)   24
# 46                         Squad Club Atlético Colón  Jan 26, 1995 (23)   23
# 49                      Squad Club Atlético Belgrano  Jan 19, 1994 (24)   24
# 56              Squad Club Atlético Unión (Santa Fe)   Jun 3, 1997 (21)   21
# 58      Squad Asociación Atlética Argentinos Juniors   May 6, 1997 (21)   21
# 83               Squad Club Atlético San Martín (SJ)  Aug 15, 1996 (22)   22
# 88     Squad Club Deportivo Godoy Cruz Antonio Tomba   Jul 7, 1994 (24)   24
# 89      Squad Asociación Atlética Argentinos Juniors  Dec 24, 1998 (19)   19
#
#      foot  squad_num  total_xG  total_xA  total_xG+xA  goals  xG+xA/90  \
# 7   right       26.0      3.53      0.31         3.84    2.0  0.379412
# 14  right       15.0      2.95      2.01         4.96    3.0  0.508815
# 17   left        7.0      2.65      0.66         3.31    2.0  0.350127
# 18  right       29.0      2.62      1.54         4.16    3.0  0.496738
# 26  right       26.0      2.14      0.72         2.86    3.0  0.301006
# 28  right       16.0      2.12      1.00         3.12    2.0  0.318548
# 30   left        6.0      2.09      0.93         3.02    1.0  0.318112
# 39  right        7.0      2.00      0.72         2.72    4.0  0.354329
# 44   left        7.0      1.86      0.47         2.33    1.0  0.351227
# 46  right        9.0      1.77      1.28         3.05    0.0  0.653234
# 49  right       11.0      1.71      1.04         2.75    1.0  0.408652
# 56   left       22.0      1.59      1.22         2.81    1.0  0.428221
# 58      -       27.0      1.52      1.06         2.58    1.0  0.600776
# 83  right       32.0      1.21      0.99         2.20    0.0  0.402425
# 88  right       11.0      1.15      0.51         1.66    0.0  0.352566
# 89  right       10.0      1.14      0.72         1.86    1.0  0.364640
#
#     transfer_value(USD)  total_minutes_played
# 7                  1.71            910.883333
# 14                 2.29            877.333333
# 17                 0.17            850.833333
# 18                 3.43            753.716667
# 26                 0.80            855.133333
# 28                 3.43            881.500000
# 30                 2.86            854.416667
# 39                 0.06            690.883333
# 44                 0.69            597.050000
# 46                 1.71            420.216667
# 49                 0.86            605.650000
# 56                 1.44            590.583333
# 58                 0.17            386.500000
# 83                 0.46            492.016667
# 88                 3.15            423.750000
# 89                 4.57            459.083333

# %% [markdown]
# ### scatter plots of people of interest (price vs xg, age vs xg)

# %%
# fig, ax = plt.subplots()
# ax.scatter(yp_xgb['xG+xA/90'], yp_xgb['transfer_value(USD)'])
# ax.set_title('xG+xA/90 vs Transfer Value for Players Younger than 25')
# ax.set_xlim([0, 1])
# ax.set_ylim([0, 5])

# %%
fig, ax = plt.subplots()
ax.scatter(yp_xgb['transfer_value(USD)'], yp_xgb['xG+xA/90'], alpha=0.8)
ax.set_title('xG+xA/90 vs Transfer Value for Players Younger than 25')
ax.set_xlabel('Player Value (USD)')
ax.set_ylabel('xG+xA/90')
ax.set_xlim([0, 5])
ax.set_ylim([0, 1])
# Out:
# (0, 1)

# %% [markdown]
# # probability by area

# %%
from create_shot_coordinates import shot_probability_player, coord_table

# %%
six, eighteen, eighteen_plus, left_box, right_box = shot_probability_player()

# %% [markdown]
# ### prob of scoring with 6-yards

# %%
six_yard_shot = coord_table(-10, 10, 2, 2, 6, 2)

p_random_forest6 = rf_model.predict_proba(six)
p_gradient_boost6 =  gb_model.predict_proba(six)
p_xgboost6 = xgb_model.predict_proba(six)

p_6_rf = p_random_forest6.sum(axis=0)[1] / len(p_random_forest6)
p_6_gb = p_gradient_boost6.sum(axis=0)[1] / len(p_gradient_boost6)
p_6_xgb = p_xgboost6.sum(axis=0)[1] / len(p_xgboost6)
p_6_e = (p_6_rf + p_6_gb + p_6_xgb) / 3

print(p_6_rf)
print(p_6_gb)
print(p_6_xgb)
print(p_6_e)
# Out:
# 0.3679635583054888
# 0.398481654643136
# 0.40284466020988696
# 0.38976329105283725
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
fig, ax = plt.subplots()
ax.scatter(six_yard_shot['shot_coord_x1'], six_yard_shot['shot_coord_y1'])
# ax.scatter(shot_distance_df['pass_coord_x1'], shot_distance_df['pass_coord_y1'], color='red')
# ax.scatter(transposed_df['pass_coord_x2'], transposed_df['pass_coord_y2'], color='yellow')
ax.set_title('xG of Shots Inside the Six (RF:0.368, GB: 0.398, XGB: 0.403, ENS: 0.390)')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')

# %% [markdown]
# ### prob of scoring inside 18

# %%
eighteen_yard_shot = coord_table(-10, 10, 2, 8, 18, 2)

p_random_forest18 = rf_model.predict_proba(eighteen)
p_gradient_boost18 =  gb_model.predict_proba(eighteen)
p_xgboost18 = xgb_model.predict_proba(eighteen)

p_18_rf = p_random_forest18.sum(axis=0)[1] / len(p_random_forest18)
p_18_gb = p_gradient_boost18.sum(axis=0)[1] / len(p_gradient_boost18)
p_18_xgb = p_xgboost18.sum(axis=0)[1] / len(p_xgboost18)
p_18_e = (p_18_rf + p_18_gb + p_18_xgb) / 3

print(p_18_rf)
print(p_18_gb)
print(p_18_xgb)
print(p_18_e)
# Out:
# 0.11718742891408605
# 0.12010388945760694
# 0.14649878126202207
# 0.12793003321123833
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
fig, ax = plt.subplots()
ax.scatter(eighteen_yard_shot['shot_coord_x1'], eighteen_yard_shot['shot_coord_y1'], color='red')
# ax.scatter(shot_distance_df['pass_coord_x1'], shot_distance_df['pass_coord_y1'], color='red')
# ax.scatter(transposed_df['pass_coord_x2'], transposed_df['pass_coord_y2'], color='yellow')
ax.set_title('xG of Shots Inside 18-yard Box (RF:0.117, GB: 0.120, XGB: 0.146, EN: 0.128')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')

# %% [markdown]
# ### prob of scoring outside 18

# %%
beyond_eighteen_yard_shot = coord_table(-22, 22, 2, 20, 30, 2)

p_random_forest18p = rf_model.predict_proba(eighteen_plus)
p_gradient_boost18p =  gb_model.predict_proba(eighteen_plus)
p_xgboost18p = xgb_model.predict_proba(eighteen_plus)

p_18p_rf = p_random_forest18p.sum(axis=0)[1] / len(p_random_forest18p)
p_18p_gb = p_gradient_boost18p.sum(axis=0)[1] / len(p_gradient_boost18p)
p_18p_xgb = p_xgboost18p.sum(axis=0)[1] / len(p_xgboost18p)
p_18p_e = (p_18p_rf + p_18p_gb + p_18p_xgb) / 3

print(p_18p_rf)
print(p_18p_gb)
print(p_18p_xgb)
print(p_18p_e)
# Out:
# 0.05648514065127861
# 0.04482416328090801
# 0.057187861290530884
# 0.052832388407572504
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
fig, ax = plt.subplots()
ax.scatter(beyond_eighteen_yard_shot['shot_coord_x1'], beyond_eighteen_yard_shot['shot_coord_y1'], color='yellow')
# ax.scatter(shot_distance_df['pass_coord_x1'], shot_distance_df['pass_coord_y1'], color='red')
# ax.scatter(transposed_df['pass_coord_x2'], transposed_df['pass_coord_y2'], color='yellow')
ax.set_title('xG of Shots Beyond 18-yard Box (RF:0.056, GB: 0.044, XGB: 0.057, ENS: 0.053)')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')

# %% [markdown]
# ### prob of scoring inside 18, left of six

# %%
left_six_yard_shot = coord_table(12, 22, 2, 3, 18, 3)

p_random_forest6l = rf_model.predict_proba(left_box)
p_gradient_boost6l =  gb_model.predict_proba(left_box)
p_xgboost6l = xgb_model.predict_proba(left_box)

p_6l_rf = p_random_forest6l.sum(axis=0)[1] / len(p_random_forest6l)
p_6l_gb = p_gradient_boost6l.sum(axis=0)[1] / len(p_gradient_boost6l)
p_6l_xgb = p_xgboost6l.sum(axis=0)[1] / len(p_xgboost6l)
p_6l_e = (p_6l_rf + p_6l_gb + p_6l_xgb) / 3

print(p_6l_rf)
print(p_6l_gb)
print(p_6l_xgb)
print(p_6l_e)
# Out:
# 0.06491957944716804
# 0.08951621390170779
# 0.075130475891961
# 0.07652208974694562
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
fig, ax = plt.subplots()
ax.scatter(left_six_yard_shot['shot_coord_x1'], left_six_yard_shot['shot_coord_y1'], color='green')
ax.set_title('xG of Shots Left of Six-yard Box (RF:0.065, GB: 0.090, XGB: 0.075, EN: 0.077)')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')

# %%
right_six_yard_shot = coord_table(-12, -22, -2, 3, 18, 3)

p_random_forest6r = rf_model.predict_proba(right_box)
p_gradient_boost6r =  gb_model.predict_proba(right_box)
p_xgboost6r = xgb_model.predict_proba(right_box)

p_6r_rf = p_random_forest6r.sum(axis=0)[1] / len(p_random_forest6r)
p_6r_gb = p_gradient_boost6r.sum(axis=0)[1] / len(p_gradient_boost6r)
p_6r_xgb = p_xgboost6r.sum(axis=0)[1] / len(p_xgboost6r)
p_6r_e = (p_6r_rf + p_6r_gb + p_6r_xgb) / 3

print(p_6r_rf)
print(p_6r_gb)
print(p_6r_xgb)
print(p_6r_e)
# Out:
# 0.07387036915536958
# 0.08763064818748958
# 0.08918862210379706
# 0.08356321314888542
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished

# %%
fig, ax = plt.subplots()
ax.scatter(right_six_yard_shot['shot_coord_x1'], right_six_yard_shot['shot_coord_y1'], color='purple')
ax.set_title('xG of shots beyond left of six yard box (RF:0.074, GB: 0.088, XGB: 0.089, EN: 0.084)')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')

# %% [markdown]
# # Player shot chart
#
# using ensemble table, mapping player shot_charts

# %%
#players of interest
ens_sl_final[(ens_sl_final['age'] < 25) & (ens_sl_final['xG+xA/90'] > 0.3) & (ens_sl_final['transfer_value(USD)'] < 5) & (ens_sl_final['total_minutes_played'] > 300)]
# Out:
#     player_id           player_name  \
# 7    135386.0     Leonardo Sequeira
# 14   172565.0       Nicolás Reniero
# 17   193188.0          Gastón Togni
# 18   114108.0     Nicolás Fernández
# 26   121341.0        Héctor Fértoli
# 28   185745.0       Lucas Robertone
# 30   163041.0     Alexander Barboza
# 39   172801.0         Nahuel Bustos
# 44   118855.0        Nazareno Solís
# 46   172730.0    Nicolás Leguizamón
# 49    95766.0         Adrián Balboa
# 56   175369.0      Franco Troyansky
# 58   131511.0  Francisco Illarregui
# 83   122082.0      Franco Cristaldo
# 88   123767.0        Victorio Ramis
# 89   189736.0   Alexis Mac Allister
#
#                                                 club           birthday  age  \
# 7                       Squad Club Atlético Belgrano  Apr 26, 1995 (23)   23
# 14        Squad Club Atlético San Lorenzo de Almagro  Mar 18, 1995 (23)   23
# 17  Squad Club Social y Deportivo Defensa y Justicia  Sep 20, 1997 (21)   21
# 18  Squad Club Social y Deportivo Defensa y Justicia   Feb 8, 1996 (22)   22
# 26             Squad Club Atlético Newell's Old Boys   Dec 3, 1994 (24)   24
# 28               Squad Club Atlético Vélez Sarsfield  Mar 18, 1997 (21)   21
# 30  Squad Club Social y Deportivo Defensa y Justicia  Mar 16, 1995 (23)   23
# 39                      Squad Club Atlético Talleres   Jul 4, 1998 (20)   20
# 44               Squad Club Atlético San Martín (SJ)  Apr 22, 1994 (24)   24
# 46                         Squad Club Atlético Colón  Jan 26, 1995 (23)   23
# 49                      Squad Club Atlético Belgrano  Jan 19, 1994 (24)   24
# 56              Squad Club Atlético Unión (Santa Fe)   Jun 3, 1997 (21)   21
# 58      Squad Asociación Atlética Argentinos Juniors   May 6, 1997 (21)   21
# 83               Squad Club Atlético San Martín (SJ)  Aug 15, 1996 (22)   22
# 88     Squad Club Deportivo Godoy Cruz Antonio Tomba   Jul 7, 1994 (24)   24
# 89      Squad Asociación Atlética Argentinos Juniors  Dec 24, 1998 (19)   19
#
#      foot  squad_num  total_xG  total_xA  total_xG+xA  goals  xG+xA/90  \
# 7   right       26.0      3.53      0.31         3.84    2.0  0.379412
# 14  right       15.0      2.95      2.01         4.96    3.0  0.508815
# 17   left        7.0      2.65      0.66         3.31    2.0  0.350127
# 18  right       29.0      2.62      1.54         4.16    3.0  0.496738
# 26  right       26.0      2.14      0.72         2.86    3.0  0.301006
# 28  right       16.0      2.12      1.00         3.12    2.0  0.318548
# 30   left        6.0      2.09      0.93         3.02    1.0  0.318112
# 39  right        7.0      2.00      0.72         2.72    4.0  0.354329
# 44   left        7.0      1.86      0.47         2.33    1.0  0.351227
# 46  right        9.0      1.77      1.28         3.05    0.0  0.653234
# 49  right       11.0      1.71      1.04         2.75    1.0  0.408652
# 56   left       22.0      1.59      1.22         2.81    1.0  0.428221
# 58      -       27.0      1.52      1.06         2.58    1.0  0.600776
# 83  right       32.0      1.21      0.99         2.20    0.0  0.402425
# 88  right       11.0      1.15      0.51         1.66    0.0  0.352566
# 89  right       10.0      1.14      0.72         1.86    1.0  0.364640
#
#     transfer_value(USD)  total_minutes_played
# 7                  1.71            910.883333
# 14                 2.29            877.333333
# 17                 0.17            850.833333
# 18                 3.43            753.716667
# 26                 0.80            855.133333
# 28                 3.43            881.500000
# 30                 2.86            854.416667
# 39                 0.06            690.883333
# 44                 0.69            597.050000
# 46                 1.71            420.216667
# 49                 0.86            605.650000
# 56                 1.44            590.583333
# 58                 0.17            386.500000
# 83                 0.46            492.016667
# 88                 3.15            423.750000
# 89                 4.57            459.083333

# %%
nah_bustos = shots_df[shots_df['player_id'] == 172801.0 ]

# %%
nah_bustos.head()
# Out:
#      game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 1230  448612   172801.0          10.67           0.44           3.63
# 1463  448618   172801.0           4.89           3.56          12.41
# 1470  448618   172801.0          11.56           6.22           3.03
# 1474  448618   172801.0          16.00          10.22          -3.03
# 1758  448632   172801.0          17.78           0.89          -3.63
#
#       shot_coord_y2 shot_coord_z1  shot_coord_z2   shot_id shot_type team_id  \
# 1230           3.03            -1           0.08  22939571         9     135
# 1463           3.03            -1           0.32  23079362         9     135
# 1470          -0.61            -1           0.73  23081429        35     135
# 1474         -15.13            -1          -1.00  23082476        33     135
# 1758           0.61            -1          -1.00  23209935        33     135
#
#       time_of_event(min)  passed_from_id  pass_coord_x1  pass_coord_x2  \
# 1230           11.700000        104594.0          12.44          12.44
# 1463           12.183333         70297.0           1.78           5.33
# 1470           56.833333             NaN            NaN            NaN
# 1474           86.200000             NaN            NaN            NaN
# 1758           23.483333        190843.0          19.11          24.44
#
#       pass_coord_y1  pass_coord_y2  pass_coord_z1  pass_coord_z2  corner_kick  \
# 1230          -1.21          -1.21           -1.0           -1.0          0.0
# 1463          27.24           6.66           -1.0           -1.0          1.0
# 1470            NaN            NaN            NaN            NaN          0.0
# 1474            NaN            NaN            NaN            NaN          0.0
# 1758         -11.80           2.42           -1.0           -1.0          0.0
#
#       shot_distance  shot_angle assisted_shot is_penalty_attempt  is_goal
# 1230      11.270572   18.788622             1                  0      1.0
# 1463      13.338673   68.493721             1                  0      1.0
# 1470      11.950502   14.687436             0                  0      0.0
# 1474      16.284376  -10.723401             0                  0      0.0
# 1758      18.146771  -11.539040             1                  0      0.0

# %%
fig, ax = plt.subplots()
ax.scatter(nah_bustos[nah_bustos['is_goal'] == 1.0]['shot_coord_x1'], nah_bustos[nah_bustos['is_goal'] ==1.0]['shot_coord_y1'], color='red', alpha = 0.5)
ax.scatter(nah_bustos[nah_bustos['is_goal'] == 0.0]['shot_coord_x1'], nah_bustos[nah_bustos['is_goal'] == 0.0]['shot_coord_y1'], color='blue', alpha = 0.3)
ax.set_title('Shot Chart of Nahuel Bustos: xG+xA/90: 0.354')
ax.set_xlim([88.88, 0])
ax.set_ylim([-30.76, 30.76])
ax.axvline(6, ymin=-10, ymax=10)
ax.axvline(18)
ax.axhline(10, xmax=6)
ax.axhline(-10, xmax=6)
ax.axhline(22, xmax=18)
ax.axhline(-22, xmax=18)
ax.set_facecolor('xkcd:lightgreen')
