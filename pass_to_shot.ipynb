# %%
import pprint
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from json_shot_scraper import flatten_shot, flatten_goal, flatten_complete_pass, flatten_incomplete_pass
from  player_scraper import flatten_player, flatten_sub
from dataframe_cleaner import shot_to_pass
# Out:
# [autoreload of json_shot_scraper failed: Traceback (most recent call last):
#   File "/Users/david/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/david/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/Users/david/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/david/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/david/galvanize/super_liga_xg/json_shot_scraper.py", line 16
#     'shot_coord_x1': shot_data['coord']['1']['x'],
#                    ^
# SyntaxError: invalid syntax
# ]

# %%
with open ('data/448588.json') as f:
    data = json.load(f)
    game_id = 448588

# %%
shots = list(data['incidences']['shots'].items())
shot_list_dicts = [flatten_shot(shot, game_id) for shot in shots]
shot_df = pd.DataFrame(shot_list_dicts)

# %%
shot_df.head()
# Out:
#    caught_by  game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0        NaN   448588      28126           0.75           0.99          -0.07
# 1        NaN   448588     136947          -0.48          -0.99           0.02
# 2        NaN   448588       1325          -0.75          -0.99          -0.14
# 3    49859.0   448588     118855          -0.43          -0.96          -0.06
# 4        NaN   448588       1325          -0.47          -1.00          -0.17
#
#    shot_coord_y2  shot_coord_z1  shot_coord_z2   shot_id  shot_type  t_half  \
# 0           0.06             -1          -1.00  22822829         33       1
# 1          -0.12             -1          -1.00  22822912         33       1
# 2           0.21             -1          -1.00  22822926         33       1
# 3           0.07             -1           0.33  22822958         35       1
# 4          -0.27             -1          -1.00  22823013         33       1
#
#    t_min  t_sec  team_id  time_of_event(min)
# 0      3     30       17            3.500000
# 1      6     55      134            6.916667
# 2      7     30      134            7.500000
# 3      8     40      134            8.666667
# 4     10     31      134           10.516667

# %%
shot_df[shot_df['shot_type']==11]
# Out:
#     caught_by  game_id  player_id  shot_coord_x1  shot_coord_x2  \
# 8         NaN   448588      51413           0.96           1.00
# 13        NaN   448588      47487           0.77           0.99
#
#     shot_coord_y1  shot_coord_y2  shot_coord_z1  shot_coord_z2   shot_id  \
# 8           -0.18          -0.11             -1           0.25  22823953
# 13          -0.06          -0.11             -1           0.18  22826185
#
#     shot_type  t_half  t_min  t_sec  team_id  time_of_event(min)
# 8          11       1     34     33       17           34.550000
# 13         11       2     53      5      134           53.083333

# %%
goals = list(data['incidences']['goals'].items())
goal_list_dicts = [flatten_goal(goal, game_id) for goal in goals]
goal_df = pd.DataFrame(goal_list_dicts)

# %%
goal_df
# Out:
#    assisted_by  game_id   goal_id  player_id  shot_coord_x1  shot_coord_x2  \
# 0      28126.0   448588  22823436      54702           0.83           1.00
# 1          NaN   448588  22823953      51413           0.96           1.00
# 2          NaN   448588  22825994      54702          -0.67          -0.98
# 3     118855.0   448588  22826185      47487           0.77           0.99
# 4          NaN   448588  22826995      77919          -0.73          -1.00
#
#    shot_coord_y1  shot_coord_y2  shot_coord_z1  shot_coord_z2  shot_type  \
# 0          -0.14           0.08             -1           0.10          9
# 1          -0.18          -0.11             -1           0.25         11
# 2           0.17          -0.13             -1           0.18          9
# 3          -0.06          -0.11             -1           0.18         11
# 4          -0.01           0.06             -1           0.18         13
#
#    team_id
# 0       17
# 1       17
# 2       17
# 3      134
# 4       17

# %%
completed_passes = list(data['incidences']['correctPasses'].items())

# %%
completed_list_dicts = [flatten_complete_pass(apass, game_id) for apass in completed_passes]

# %%
completed_passes_df = pd.DataFrame(completed_list_dicts)

# %%
completed_passes_df.head()
# Out:
#    game_id  pass_coord_x1  pass_coord_x2  pass_coord_y1  pass_coord_y2  \
# 0   448588           0.05          -0.20           0.09          -0.49
# 1   448588          -0.24          -0.09          -0.41          -0.61
# 2   448588          -0.21          -0.44          -0.81          -0.79
# 3   448588          -0.55          -0.56          -0.72          -0.41
# 4   448588          -0.67          -0.50          -0.24           0.53
#
#    pass_coord_z1  pass_coord_z2  pass_player  pass_type  rec_player  t_half  \
# 0             -1             -1        28126        180       37092       1
# 1             -1             -1        37092        180         657       1
# 2             -1             -1          657        180       51413       1
# 3             -1             -1        51413        180         483       1
# 4             -1             -1          483        180      153417       1
#
#    t_min  t_sec  team_id  time_of_event(min)
# 0      0      5       17            0.083333
# 1      0     10       17            0.166667
# 2      0     11       17            0.183333
# 3      0     13       17            0.216667
# 4      0     14       17            0.233333

# %%
shot_df
# Out:
#     caught_by  game_id  player_id  shot_coord_x1  shot_coord_x2  \
# 0         NaN   448588      28126           0.75           0.99
# 1         NaN   448588     136947          -0.48          -0.99
# 2         NaN   448588       1325          -0.75          -0.99
# 3     49859.0   448588     118855          -0.43          -0.96
# 4         NaN   448588       1325          -0.47          -1.00
# 5         NaN   448588      54702           0.83           1.00
# 6     49859.0   448588      27793          -0.67          -0.94
# 7         NaN   448588      46601           0.97           1.00
# 8         NaN   448588      51413           0.96           1.00
# 9         NaN   448588      27793          -0.85          -0.99
# 10    49859.0   448588     122082          -0.46          -0.95
# 11        NaN   448588     136947           0.54           1.00
# 12        NaN   448588      54702          -0.67          -0.98
# 13        NaN   448588      47487           0.77           0.99
# 14    49859.0   448588      47487           0.72           0.97
# 15    49859.0   448588     176520           0.77           0.97
# 16        NaN   448588      77919          -0.73          -1.00
# 17        NaN   448588      47487           0.79           0.99
# 18        NaN   448588      51413          -0.48          -1.00
#
#     shot_coord_y1  shot_coord_y2  shot_coord_z1  shot_coord_z2   shot_id  \
# 0           -0.07           0.06             -1          -1.00  22822829
# 1            0.02          -0.12             -1          -1.00  22822912
# 2           -0.14           0.21             -1          -1.00  22822926
# 3           -0.06           0.07             -1           0.33  22822958
# 4           -0.17          -0.27             -1          -1.00  22823013
# 5           -0.14           0.08             -1           0.10  22823436
# 6           -0.36          -0.04             -1           0.08  22823456
# 7            0.45           0.16             -1          -1.00  22823838
# 8           -0.18          -0.11             -1           0.25  22823953
# 9            0.31          -0.26             -1          -1.00  22824052
# 10           0.00          -0.02             -1           0.08  22824659
# 11          -0.05           0.34             -1          -1.00  22825743
# 12           0.17          -0.13             -1           0.18  22825994
# 13          -0.06          -0.11             -1           0.18  22826185
# 14           0.11          -0.02             -1           0.10  22826510
# 15           0.06           0.07             -1           0.36  22826843
# 16          -0.01           0.06             -1           0.18  22826995
# 17          -0.09          -0.09             -1          -1.00  22827507
# 18           0.36           0.07             -1          -1.00  22827782
#
#     shot_type  t_half  t_min  t_sec  team_id  time_of_event(min)
# 0          33       1      3     30       17            3.500000
# 1          33       1      6     55      134            6.916667
# 2          33       1      7     30      134            7.500000
# 3          35       1      8     40      134            8.666667
# 4          33       1     10     31      134           10.516667
# 5           9       1     22     30       17           22.500000
# 6          35       1     24      1      134           24.016667
# 7          33       1     32     58       17           32.966667
# 8          11       1     34     33       17           34.550000
# 9          33       1     36     20      134           36.333333
# 10         35       1     44     48      134           44.800000
# 11         33       2     45     39      134           45.650000
# 12          9       2     49     18       17           49.300000
# 13         11       2     53      5      134           53.083333
# 14         35       2     57     32      134           57.533333
# 15         35       2     65     12      134           65.200000
# 16         13       2     71     26       17           71.433333
# 17         33       2     80     53      134           80.883333
# 18         33       2     85     12       17           85.200000

# %%
completed_passes_df[(completed_passes_df['rec_player']==51413) & (completed_passes_df['pass_player'] == 657)]
# Out:
#      game_id  pass_coord_x1  pass_coord_x2  pass_coord_y1  pass_coord_y2  \
# 2     448588          -0.21          -0.44          -0.81          -0.79
# 273   448588          -0.24          -0.04           0.30          -0.07
# 282   448588           0.52           0.30          -0.70          -0.56
#
#      pass_coord_z1  pass_coord_z2  pass_player  pass_type  rec_player  t_half  \
# 2               -1             -1          657        180       51413       1
# 273             -1             -1          657        180       51413       1
# 282             -1             -1          657        180       51413       1
#
#      t_min  t_sec  team_id  time_of_event(min)
# 2        0     11       17            0.183333
# 273     40     57       17           40.950000
# 282     41     42       17           41.700000

# %%
shooter_id = shot_df.iloc[0, :]['player_id']
shoot_time = shot_df.iloc[0, :]['time_of_event(min)']
pass_shot_df = completed_passes_df[(completed_passes_df['rec_player']== shooter_id) & (completed_passes_df['time_of_event(min)'] < shoot_time) & (completed_passes_df['time_of_event(min)'] > shoot_time - .16667)]
pass_shot_df
# Out:
#     game_id  pass_coord_x1  pass_coord_x2  pass_coord_y1  pass_coord_y2  \
# 31   448588           0.42           0.59           -0.5          -0.16
#
#     pass_coord_z1  pass_coord_z2  pass_player  pass_type  rec_player  t_half  \
# 31             -1             -1        54702        180       28126       1
#
#     t_min  t_sec  team_id  time_of_event(min)
# 31      3     25       17            3.416667

# %%
tdf = shot_df.iloc[0:2, :].copy()

# %%
tdf.iloc[-1, :]
# Out:
# caught_by                  NaN
# game_id                 448588
# player_id               136947
# shot_coord_x1            -0.48
# shot_coord_x2            -0.99
# shot_coord_y1             0.02
# shot_coord_y2            -0.12
# shot_coord_z1               -1
# shot_coord_z2               -1
# shot_id               22822912
# shot_type                   33
# t_half                       1
# t_min                        6
# t_sec                       55
# team_id                    134
# time_of_event(min)     6.91667
# Name: 1, dtype: object

# %%
shot_df.head()
# Out:
#    caught_by  game_id  player_id  shot_coord_x1  shot_coord_x2  shot_coord_y1  \
# 0        NaN   448588      28126           0.75           0.99          -0.07
# 1        NaN   448588     136947          -0.48          -0.99           0.02
# 2        NaN   448588       1325          -0.75          -0.99          -0.14
# 3    49859.0   448588     118855          -0.43          -0.96          -0.06
# 4        NaN   448588       1325          -0.47          -1.00          -0.17
#
#    shot_coord_y2  shot_coord_z1  shot_coord_z2   shot_id  shot_type  t_half  \
# 0           0.06             -1          -1.00  22822829         33       1
# 1          -0.12             -1          -1.00  22822912         33       1
# 2           0.21             -1          -1.00  22822926         33       1
# 3           0.07             -1           0.33  22822958         35       1
# 4          -0.27             -1          -1.00  22823013         33       1
#
#    t_min  t_sec  team_id  time_of_event(min)
# 0      3     30       17            3.500000
# 1      6     55      134            6.916667
# 2      7     30      134            7.500000
# 3      8     40      134            8.666667
# 4     10     31      134           10.516667

# %%
# for indx, row in shot_df.iterrows():
# #     print(row)
#     shooter_id = row['player_id']
#     shoot_time = row['time_of_event(min)']
#     possible_pass_df =  completed_passes_df[(completed_passes_df['rec_player']== shooter_id) & (completed_passes_df['time_of_event(min)'] < shoot_time) & (completed_passes_df['time_of_event(min)'] > shoot_time -3)]
#     if len(possible_pass_df) == 0:
#         shot_df.loc[indx, 'passed_from_id'] = None
#     elif len(possible_pass_df) > 1:
#         shot_df.loc[indx, 'passed_from_id'] = possible_pass_df.iloc[-1, :]['pass_player']   
#     else:
#         shot_df.loc[indx, 'passed_from_id'] = possible_pass_df.iloc[0, :]['pass_player']

# %%
shot_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1         NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2         NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3     49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4         NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 6     49859.0     -0.67     -0.94     -0.36     -0.04        -1      0.08
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 9         NaN     -0.85     -0.99      0.31     -0.26        -1     -1.00
# 10    49859.0     -0.46     -0.95      0.00     -0.02        -1      0.08
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 12        NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 16        NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
# 18        NaN     -0.48     -1.00      0.36      0.07        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588      28126  22822829         33       1      3     30       17
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 5    448588      54702  22823436          9       1     22     30       17
# 6    448588      27793  22823456         35       1     24      1      134
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 11   448588     136947  22825743         33       2     45     39      134
# 12   448588      54702  22825994          9       2     49     18       17
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 16   448588      77919  22826995         13       2     71     26       17
# 17   448588      47487  22827507         33       2     80     53      134
# 18   448588      51413  22827782         33       2     85     12       17
#
#     time_of_event(min)  passed_from_id
# 0             3.500000         54702.0
# 1             6.916667             NaN
# 2             7.500000        118855.0
# 3             8.666667         46638.0
# 4            10.516667        136947.0
# 5            22.500000         28126.0
# 6            24.016667             NaN
# 7            32.966667         63477.0
# 8            34.550000         37092.0
# 9            36.333333          3173.0
# 10           44.800000          1325.0
# 11           45.650000             NaN
# 12           49.300000             NaN
# 13           53.083333             NaN
# 14           57.533333             NaN
# 15           65.200000         24719.0
# 16           71.433333         54702.0
# 17           80.883333        136947.0
# 18           85.200000        148044.0

# %%
# Out:
#    caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0        NaN      0.75      0.99     -0.07      0.06        -1      -1.0
# 1        NaN     -0.48     -0.99      0.02     -0.12        -1      -1.0
#
#    game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0   448588      28126  22822829         33       1      3     30       17
# 1   448588     136947  22822912         33       1      6     55      134
#
#    time_of_event(min)  passed_to_by  new
# 0            3.500000           332  3.0
# 1            6.916667           441  NaN

# %%
shot_pass_df = shot_to_pass(shot_df, completed_passes_df)

# %%
goal_df
# Out:
#    assisted_by  game_id   goal_id  player_id  shot_coord_x1  shot_coord_x2  \
# 0      28126.0   448588  22823436      54702           0.83           1.00
# 1          NaN   448588  22823953      51413           0.96           1.00
# 2          NaN   448588  22825994      54702          -0.67          -0.98
# 3     118855.0   448588  22826185      47487           0.77           0.99
# 4          NaN   448588  22826995      77919          -0.73          -1.00
#
#    shot_coord_y1  shot_coord_y2  shot_coord_z1  shot_coord_z2  shot_type  \
# 0          -0.14           0.08             -1           0.10          9
# 1          -0.18          -0.11             -1           0.25         11
# 2           0.17          -0.13             -1           0.18          9
# 3          -0.06          -0.11             -1           0.18         11
# 4          -0.01           0.06             -1           0.18         13
#
#    team_id
# 0       17
# 1       17
# 2       17
# 3      134
# 4       17

# %%
shot_pass_df[shot_pass_df['shot_type']==11]
# Out:
#     caught_by  game_id  player_id  shot_coord_x1  shot_coord_x2  \
# 8         NaN   448588      51413           0.96           1.00
# 13        NaN   448588      47487           0.77           0.99
#
#     shot_coord_y1  shot_coord_y2  shot_coord_z1  shot_coord_z2   shot_id  \
# 8           -0.18          -0.11             -1           0.25  22823953
# 13          -0.06          -0.11             -1           0.18  22826185
#
#     shot_type  t_half  t_min  t_sec  team_id  time_of_event(min)  \
# 8          11       1     34     33       17           34.550000
# 13         11       2     53      5      134           53.083333
#
#     passed_from_id
# 8              NaN
# 13             NaN

# %%
completed_passes_df[completed_passes_df['pass_player'] == 118855]
# Out:
#      game_id  pass_coord_x1  pass_coord_x2  pass_coord_y1  pass_coord_y2  \
# 53    448588           0.15          -0.30           0.54           0.83
# 54    448588           0.09          -0.15           0.59           0.93
# 57    448588          -0.71          -0.74           0.81          -0.02
# 107   448588           0.33           0.33           0.65           0.41
# 120   448588          -0.98          -0.67          -0.97          -0.81
# 174   448588          -0.42          -0.33           0.79           0.70
# 295   448588          -0.23           0.00           0.32           0.71
# 297   448588          -0.11          -0.21           0.40           0.80
# 301   448588          -0.59          -0.59           0.80           0.17
# 314   448588          -0.35          -0.64          -0.70          -0.46
# 352   448588           0.41           0.14          -0.70          -0.77
# 369   448588           0.43           0.40           0.52          -0.29
# 379   448588           0.14          -0.44          -0.78          -0.60
# 404   448588          -0.02          -0.30          -0.83          -0.82
# 428   448588          -0.18           0.17           0.55           0.75
# 466   448588          -0.32          -0.70          -0.42          -0.14
#
#      pass_coord_z1  pass_coord_z2  pass_player  pass_type  rec_player  t_half  \
# 53              -1             -1       118855        180       46638       1
# 54              -1             -1       118855        180       46638       1
# 57              -1             -1       118855        180        1325       1
# 107             -1             -1       118855        180      136947       1
# 120             -1             -1       118855        180      122082       1
# 174             -1             -1       118855        180      136947       1
# 295             -1             -1       118855        180      105325       1
# 297             -1             -1       118855        180      105325       1
# 301             -1             -1       118855        180        1325       1
# 314             -1             -1       118855        180      176520       2
# 352             -1             -1       118855        180      105325       2
# 369             -1             -1       118855        180      136947       2
# 379             -1             -1       118855        180      176520       2
# 404             -1             -1       118855        180      105325       2
# 428             -1             -1       118855        180       28823       2
# 466             -1             -1       118855        180      176520       2
#
#      t_min  t_sec  team_id  time_of_event(min)
# 53       6     37      134            6.616667
# 54       7     21      134            7.350000
# 57       7     28      134            7.466667
# 107     13     23      134           13.383333
# 120     16     29      134           16.483333
# 174     24     46      134           24.766667
# 295     44     29      134           44.483333
# 297     44     34      134           44.566667
# 301     44     40      134           44.666667
# 314     45      8      134           45.133333
# 352     52     21      134           52.350000
# 369     57     19      134           57.316667
# 379     59      7      134           59.116667
# 404     64     38      134           64.633333
# 428     72     28      134           72.466667
# 466     74     52      134           74.866667

# %%
52.350 - 53.0833
# Out:
# -0.7332999999999998

# %%
60 * .733
# Out:
# 43.98
