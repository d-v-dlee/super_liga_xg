# %%
import pprint
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from json_shot_scraper import flatten_shot, flatten_goal, flatten_complete_pass, flatten_incomplete_pass
from  player_scraper import flatten_player, flatten_sub
from dataframe_cleaner import shot_to_pass

# %%
with open ('data/448588.json') as f:
    data = json.load(f)
    game_id = 448588

# %%
shots = list(data['incidences']['shots'].items())
shot_list_dicts = [flatten_shot(shot, game_id) for shot in shots]
shot_df = pd.DataFrame(shot_list_dicts)

# %%
shot_df.head()
# Out:
#    caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0        NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1        NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2        NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3    49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4        NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
#
#    game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0   448588      28126  22822829         33       1      3     30       17
# 1   448588     136947  22822912         33       1      6     55      134
# 2   448588       1325  22822926         33       1      7     30      134
# 3   448588     118855  22822958         35       1      8     40      134
# 4   448588       1325  22823013         33       1     10     31      134
#
#    time_of_event(min)
# 0            3.500000
# 1            6.916667
# 2            7.500000
# 3            8.666667
# 4           10.516667

# %%
shot_df[shot_df['shot_type']==11]
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 8    448588      51413  22823953         11       1     34     33       17
# 13   448588      47487  22826185         11       2     53      5      134
#
#     time_of_event(min)
# 8            34.550000
# 13           53.083333

# %%
goals = list(data['incidences']['goals'].items())
goal_list_dicts = [flatten_goal(goal, game_id) for goal in goals]
goal_df = pd.DataFrame(goal_list_dicts)

# %%
goal_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 2          NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
# 4          NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 2   448588  22825994      54702          9       17
# 3   448588  22826185      47487         11      134
# 4   448588  22826995      77919         13       17

# %%
completed_passes = list(data['incidences']['correctPasses'].items())

# %%
completed_list_dicts = [flatten_complete_pass(apass, game_id) for apass in completed_passes]

# %%
completed_passes_df = pd.DataFrame(completed_list_dicts)

# %%
completed_passes_df.head()
# Out:
#    coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  game_id  \
# 0      0.05     -0.20      0.09     -0.49        -1        -1   448588
# 1     -0.24     -0.09     -0.41     -0.61        -1        -1   448588
# 2     -0.21     -0.44     -0.81     -0.79        -1        -1   448588
# 3     -0.55     -0.56     -0.72     -0.41        -1        -1   448588
# 4     -0.67     -0.50     -0.24      0.53        -1        -1   448588
#
#    pass_player  pass_type  rec_player  t_half  t_min  t_sec  team_id  \
# 0        28126        180       37092       1      0      5       17
# 1        37092        180         657       1      0     10       17
# 2          657        180       51413       1      0     11       17
# 3        51413        180         483       1      0     13       17
# 4          483        180      153417       1      0     14       17
#
#    time_of_event(min)
# 0            0.083333
# 1            0.166667
# 2            0.183333
# 3            0.216667
# 4            0.233333

# %%
shot_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1         NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2         NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3     49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4         NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 6     49859.0     -0.67     -0.94     -0.36     -0.04        -1      0.08
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 9         NaN     -0.85     -0.99      0.31     -0.26        -1     -1.00
# 10    49859.0     -0.46     -0.95      0.00     -0.02        -1      0.08
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 12        NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 16        NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
# 18        NaN     -0.48     -1.00      0.36      0.07        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588      28126  22822829         33       1      3     30       17
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 5    448588      54702  22823436          9       1     22     30       17
# 6    448588      27793  22823456         35       1     24      1      134
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 11   448588     136947  22825743         33       2     45     39      134
# 12   448588      54702  22825994          9       2     49     18       17
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 16   448588      77919  22826995         13       2     71     26       17
# 17   448588      47487  22827507         33       2     80     53      134
# 18   448588      51413  22827782         33       2     85     12       17
#
#     time_of_event(min)
# 0             3.500000
# 1             6.916667
# 2             7.500000
# 3             8.666667
# 4            10.516667
# 5            22.500000
# 6            24.016667
# 7            32.966667
# 8            34.550000
# 9            36.333333
# 10           44.800000
# 11           45.650000
# 12           49.300000
# 13           53.083333
# 14           57.533333
# 15           65.200000
# 16           71.433333
# 17           80.883333
# 18           85.200000

# %%
completed_passes_df[(completed_passes_df['rec_player']==51413) & (completed_passes_df['pass_player'] == 657)]
# Out:
#      coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  game_id  \
# 2       -0.21     -0.44     -0.81     -0.79        -1        -1   448588
# 273     -0.24     -0.04      0.30     -0.07        -1        -1   448588
# 282      0.52      0.30     -0.70     -0.56        -1        -1   448588
#
#      pass_player  pass_type  rec_player  t_half  t_min  t_sec  team_id  \
# 2            657        180       51413       1      0     11       17
# 273          657        180       51413       1     40     57       17
# 282          657        180       51413       1     41     42       17
#
#      time_of_event(min)
# 2              0.183333
# 273           40.950000
# 282           41.700000

# %%
shooter_id = shot_df.iloc[0, :]['player_id']
shoot_time = shot_df.iloc[0, :]['time_of_event(min)']
pass_shot_df = completed_passes_df[(completed_passes_df['rec_player']== shooter_id) & (completed_passes_df['time_of_event(min)'] < shoot_time) & (completed_passes_df['time_of_event(min)'] > shoot_time - .16667)]
pass_shot_df
# Out:
#     coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  game_id  \
# 31      0.42      0.59      -0.5     -0.16        -1        -1   448588
#
#     pass_player  pass_type  rec_player  t_half  t_min  t_sec  team_id  \
# 31        54702        180       28126       1      3     25       17
#
#     time_of_event(min)
# 31            3.416667

# %%
tdf = shot_df.iloc[0:2, :].copy()

# %%
tdf.iloc[-1, :]
# Out:
# caught_by                  NaN
# coord_x1                 -0.48
# coord_x2                 -0.99
# coord_y1                  0.02
# coord_y2                 -0.12
# coord_z1                    -1
# coord_z2                    -1
# game_id                 448588
# player_id               136947
# shot_id               22822912
# shot_type                   33
# t_half                       1
# t_min                        6
# t_sec                       55
# team_id                    134
# time_of_event(min)     6.91667
# Name: 1, dtype: object

# %%
shot_df.head()
# Out:
#    caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0        NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1        NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2        NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3    49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4        NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
#
#    game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0   448588      28126  22822829         33       1      3     30       17
# 1   448588     136947  22822912         33       1      6     55      134
# 2   448588       1325  22822926         33       1      7     30      134
# 3   448588     118855  22822958         35       1      8     40      134
# 4   448588       1325  22823013         33       1     10     31      134
#
#    time_of_event(min)  passed_from_id
# 0            3.500000         54702.0
# 1            6.916667             NaN
# 2            7.500000        118855.0
# 3            8.666667         46638.0
# 4           10.516667        136947.0

# %%
for indx, row in shot_df.iterrows():
#     print(row)
    shooter_id = row['player_id']
    shoot_time = row['time_of_event(min)']
    possible_pass_df =  completed_passes_df[(completed_passes_df['rec_player']== shooter_id) & (completed_passes_df['time_of_event(min)'] < shoot_time) & (completed_passes_df['time_of_event(min)'] > shoot_time -3)]
    if len(possible_pass_df) == 0:
        shot_df.loc[indx, 'passed_from_id'] = None
    elif len(possible_pass_df) > 1:
        shot_df.loc[indx, 'passed_from_id'] = possible_pass_df.iloc[-1, :]['pass_player']   
    else:
        shot_df.loc[indx, 'passed_from_id'] = possible_pass_df.iloc[0, :]['pass_player']

# %%
shot_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1         NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2         NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3     49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4         NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 6     49859.0     -0.67     -0.94     -0.36     -0.04        -1      0.08
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 9         NaN     -0.85     -0.99      0.31     -0.26        -1     -1.00
# 10    49859.0     -0.46     -0.95      0.00     -0.02        -1      0.08
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 12        NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 16        NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
# 18        NaN     -0.48     -1.00      0.36      0.07        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588      28126  22822829         33       1      3     30       17
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 5    448588      54702  22823436          9       1     22     30       17
# 6    448588      27793  22823456         35       1     24      1      134
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 11   448588     136947  22825743         33       2     45     39      134
# 12   448588      54702  22825994          9       2     49     18       17
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 16   448588      77919  22826995         13       2     71     26       17
# 17   448588      47487  22827507         33       2     80     53      134
# 18   448588      51413  22827782         33       2     85     12       17
#
#     time_of_event(min)  passed_from_id
# 0             3.500000         54702.0
# 1             6.916667             NaN
# 2             7.500000        118855.0
# 3             8.666667         46638.0
# 4            10.516667        136947.0
# 5            22.500000         28126.0
# 6            24.016667             NaN
# 7            32.966667         63477.0
# 8            34.550000         37092.0
# 9            36.333333          3173.0
# 10           44.800000          1325.0
# 11           45.650000             NaN
# 12           49.300000             NaN
# 13           53.083333             NaN
# 14           57.533333             NaN
# 15           65.200000         24719.0
# 16           71.433333         54702.0
# 17           80.883333        136947.0
# 18           85.200000        148044.0

# %%
tdf['passed_to_by'] = [332, 441]

# %%
tdf.loc[0, 'new'] = 3

# %%
tdf
# Out:
#    caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0        NaN      0.75      0.99     -0.07      0.06        -1      -1.0
# 1        NaN     -0.48     -0.99      0.02     -0.12        -1      -1.0
#
#    game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0   448588      28126  22822829         33       1      3     30       17
# 1   448588     136947  22822912         33       1      6     55      134
#
#    time_of_event(min)  passed_to_by  new
# 0            3.500000           332  3.0
# 1            6.916667           441  NaN

# %%
shot_to_pass(shot_df, completed_passes_df)
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1         NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2         NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3     49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4         NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 6     49859.0     -0.67     -0.94     -0.36     -0.04        -1      0.08
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 9         NaN     -0.85     -0.99      0.31     -0.26        -1     -1.00
# 10    49859.0     -0.46     -0.95      0.00     -0.02        -1      0.08
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 12        NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 16        NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
# 18        NaN     -0.48     -1.00      0.36      0.07        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588      28126  22822829         33       1      3     30       17
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 5    448588      54702  22823436          9       1     22     30       17
# 6    448588      27793  22823456         35       1     24      1      134
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 11   448588     136947  22825743         33       2     45     39      134
# 12   448588      54702  22825994          9       2     49     18       17
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 16   448588      77919  22826995         13       2     71     26       17
# 17   448588      47487  22827507         33       2     80     53      134
# 18   448588      51413  22827782         33       2     85     12       17
#
#     time_of_event(min)  passed_from_id
# 0             3.500000         54702.0
# 1             6.916667             NaN
# 2             7.500000        118855.0
# 3             8.666667             NaN
# 4            10.516667        136947.0
# 5            22.500000         28126.0
# 6            24.016667             NaN
# 7            32.966667         63477.0
# 8            34.550000             NaN
# 9            36.333333          3173.0
# 10           44.800000          1325.0
# 11           45.650000             NaN
# 12           49.300000             NaN
# 13           53.083333             NaN
# 14           57.533333             NaN
# 15           65.200000             NaN
# 16           71.433333             NaN
# 17           80.883333             NaN
# 18           85.200000             NaN

# %%
# Out:
#      coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  game_id  \
# 0        0.05     -0.20      0.09     -0.49        -1        -1   448588
# 1       -0.24     -0.09     -0.41     -0.61        -1        -1   448588
# 2       -0.21     -0.44     -0.81     -0.79        -1        -1   448588
# 3       -0.55     -0.56     -0.72     -0.41        -1        -1   448588
# 4       -0.67     -0.50     -0.24      0.53        -1        -1   448588
# 5       -0.72     -0.54      0.76      0.79        -1        -1   448588
# 6       -0.40     -0.45      0.45      0.17        -1        -1   448588
# 7       -0.27     -0.05      0.03     -0.26        -1        -1   448588
# 8       -0.04      0.37     -0.35     -0.55        -1        -1   448588
# 9       -0.08      0.12     -0.49     -0.69        -1        -1   448588
# 10      -0.02     -0.17     -0.54     -0.66        -1        -1   448588
# 11      -0.30     -0.31     -0.58      0.02        -1        -1   448588
# 12      -0.54     -0.32      0.21      0.54        -1        -1   448588
# 13      -0.27     -0.10      0.79      0.29        -1        -1   448588
# 14      -0.19      0.21      0.29     -0.33        -1        -1   448588
# 15      -0.06      0.40     -0.37     -0.76        -1        -1   448588
# 16      -0.39     -0.40      0.72     -0.16        -1        -1   448588
# 17      -0.41      0.16     -0.18     -0.30        -1        -1   448588
# 18       0.78      0.74      0.17      0.78        -1        -1   448588
# 19      -0.58     -0.32      0.08     -0.22        -1        -1   448588
# 20      -0.39      0.29     -0.26     -0.56        -1        -1   448588
# 21      -0.28     -0.56     -0.69     -0.52        -1        -1   448588
# 22       0.01      0.49     -0.11     -0.54        -1        -1   448588
# 23       0.35      0.56     -0.83     -0.92        -1        -1   448588
# 24       0.60      0.41     -0.66     -0.63        -1        -1   448588
# 25       0.36      0.38     -0.62     -0.46        -1        -1   448588
# 26       0.28      0.18     -0.51     -0.31        -1        -1   448588
# 27       0.10      0.23      0.06      0.39        -1        -1   448588
# 28       0.04      0.30      0.57      0.72        -1        -1   448588
# 29       0.40      0.19      0.32     -0.20        -1        -1   448588
# ..        ...       ...       ...       ...       ...       ...      ...
# 580     -0.48     -0.59      0.83      0.51        -1        -1   448588
# 581     -0.68     -0.62      0.72      0.61        -1        -1   448588
# 582     -0.10      0.18      0.37     -0.86        -1        -1   448588
# 583      0.82      0.58      0.21      0.84        -1        -1   448588
# 584      0.49      0.86      0.69      0.18        -1        -1   448588
# 585      0.78      0.59      0.32      0.11        -1        -1   448588
# 586      0.61      0.73      0.08     -0.18        -1        -1   448588
# 587      0.49      0.37      0.01     -0.43        -1        -1   448588
# 588      0.27      0.27     -0.24     -0.24        -1        -1   448588
# 589      0.31     -0.63     -0.17      0.89        -1        -1   448588
# 590     -0.71     -0.76      0.76      0.51        -1        -1   448588
# 591     -0.69     -0.69      0.57      0.57        -1        -1   448588
# 592      0.33      0.25      0.15     -0.36        -1        -1   448588
# 593     -0.24     -0.24     -0.73     -0.74        -1        -1   448588
# 594      0.01      0.15     -0.53     -0.51        -1        -1   448588
# 595      0.21      0.06     -0.64     -0.35        -1        -1   448588
# 596      0.18      0.13     -0.25     -0.10        -1        -1   448588
# 597     -0.10     -0.32     -0.18     -0.63        -1        -1   448588
# 598     -0.55     -0.49     -0.44     -0.22        -1        -1   448588
# 599     -0.54     -0.84     -0.31      0.73        -1        -1   448588
# 600     -0.91     -0.40      0.96      0.00        -1        -1   448588
# 601      0.53      0.14     -0.37     -0.75        -1        -1   448588
# 602     -0.24     -0.48     -0.41     -0.69        -1        -1   448588
# 603     -0.42     -0.36     -0.68     -0.23        -1        -1   448588
# 604      0.01     -0.22     -0.55     -0.33        -1        -1   448588
# 605     -0.33      0.08     -0.30     -0.29        -1        -1   448588
# 606      0.12      0.11     -0.32      0.22        -1        -1   448588
# 607      0.17     -0.07      0.36      0.41        -1        -1   448588
# 608     -0.27     -0.42      0.38     -0.60        -1        -1   448588
# 609     -0.41     -0.57     -0.35     -0.46        -1        -1   448588
#
#      pass_player  pass_type  rec_player  t_half  t_min  t_sec  team_id  \
# 0          28126        180       37092       1      0      5       17
# 1          37092        180         657       1      0     10       17
# 2            657        180       51413       1      0     11       17
# 3          51413        180         483       1      0     13       17
# 4            483        180      153417       1      0     14       17
# 5         153417        180       63477       1      0     20       17
# 6          63477        180       37092       1      0     22       17
# 7          53904        180       37092       1      0     25       17
# 8          37092        180       54702       1      0     28       17
# 9            483        180       53904       1      0     42       17
# 10         53904        180         483       1      0     44       17
# 11           483        180      153417       1      0     45       17
# 12        153417        180       46601       1      0     47       17
# 13         46601        180       53904       1      0     49       17
# 14         53904        180       37092       1      0     52       17
# 15         37092        180       51413       1      0     56       17
# 16        153417        180         483       1      1     34       17
# 17           483        180       37092       1      1     39       17
# 18         24719        180       47487       1      1     19      134
# 19           483        180       37092       1      1     59       17
# 20         37092        180       51413       1      2      2       17
# 21         51413        180      153417       1      2     45       17
# 22         28126        180       54702       1      2     50       17
# 23        136947        180        3173       1      2     25      134
# 24         54702        180       51413       1      2     58       17
# 25         51413        180       37092       1      3      1       17
# 26         37092        180       53904       1      3      3       17
# 27         53904        180      153417       1      3      6       17
# 28        153417        180       46601       1      3      9       17
# 29           657        180       37092       1      3     19       17
# ..           ...        ...         ...     ...    ...    ...      ...
# 580        77919        180       51413       2     88     39       17
# 581        51413        180       54702       2     88     43       17
# 582        47487        180      105325       2     89     19      134
# 583        49859        180         483       2     90     24       17
# 584          483        180       49859       2     90     27       17
# 585        49859        180       53904       2     90     28       17
# 586        53904        180      153417       2     90     30       17
# 587       153417        180       46601       2     90     32       17
# 588        46601        180       37092       2     90     34       17
# 589        37092        180       77919       2     90     37       17
# 590        77919        180      112671       2     90     41       17
# 591       112671        180       51413       2     90     45       17
# 592       148044        180       37092       2     91      4       17
# 593        37092        180       46601       2     91      8       17
# 594        46601        180       37092       2     91     10       17
# 595        37092        180       53904       2     91     12       17
# 596        53904        180      148044       2     91     15       17
# 597       148044        180       46601       2     91     17       17
# 598        46601        180      148044       2     91     22       17
# 599       148044        180       77919       2     91     25       17
# 600        77919        180         483       2     91     53       17
# 601       153417        180       46601       2     92     30       17
# 602        46601        180      112671       2     92     34       17
# 603       112671        180       54702       2     92     36       17
# 604       153417        180       37092       2     92     43       17
# 605        37092        180       53904       2     92     46       17
# 606        53904        180         483       2     92     48       17
# 607          483        180       77919       2     92     49       17
# 608        77919        180       46601       2     92     55       17
# 609        46601        180       54702       2     92     59       17
#
#      time_of_event(min)
# 0              0.083333
# 1              0.166667
# 2              0.183333
# 3              0.216667
# 4              0.233333
# 5              0.333333
# 6              0.366667
# 7              0.416667
# 8              0.466667
# 9              0.700000
# 10             0.733333
# 11             0.750000
# 12             0.783333
# 13             0.816667
# 14             0.866667
# 15             0.933333
# 16             1.566667
# 17             1.650000
# 18             1.316667
# 19             1.983333
# 20             2.033333
# 21             2.750000
# 22             2.833333
# 23             2.416667
# 24             2.966667
# 25             3.016667
# 26             3.050000
# 27             3.100000
# 28             3.150000
# 29             3.316667
# ..                  ...
# 580           88.650000
# 581           88.716667
# 582           89.316667
# 583           90.400000
# 584           90.450000
# 585           90.466667
# 586           90.500000
# 587           90.533333
# 588           90.566667
# 589           90.616667
# 590           90.683333
# 591           90.750000
# 592           91.066667
# 593           91.133333
# 594           91.166667
# 595           91.200000
# 596           91.250000
# 597           91.283333
# 598           91.366667
# 599           91.416667
# 600           91.883333
# 601           92.500000
# 602           92.566667
# 603           92.600000
# 604           92.716667
# 605           92.766667
# 606           92.800000
# 607           92.816667
# 608           92.916667
# 609           92.983333
#
# [610 rows x 15 columns]
