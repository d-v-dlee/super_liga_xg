# %%
import pprint
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from json_shot_scraper import flatten_shot, flatten_goal, flatten_complete_pass, flatten_incomplete_pass
from  player_scraper import flatten_player, flatten_sub

# %%
with open ('data/448588.json') as f:
    data = json.load(f)
    game_id = 448588

# %%
data.keys()
# Out:
# dict_keys(['Revision', 'lastChangedDate', 'lastChangeBy', 'match', 'status', 'venueInformation', 'broadcast', 'scoreStatus', 'players', 'teams', 'officials', 'incidences', 'deletedIncidences', 'summary', 'commentary'])

# %%
data['match'].keys()
# Out:
# dict_keys(['revision', 'matchId', 'homeTeamId', 'homeTeamName', 'awayTeamId', 'awayTeamName', 'date', 'dayName', 'scheduledStart', 'gmt', 'stadiumGMT', 'league', 'leagueId', 'competition', 'competitionId', 'competitionGender', 'week', 'weekId', 'loadLevel', 'levelName', 'coverageLevel', 'fn', 'channel', 'matchRating'])

# %%
data['match']['homeTeamId']
# Out:
# 17

# %%
data['incidences'].keys()
# Out:
# dict_keys(['goals', 'substitutions', 'clearances', 'cornerKicks', 'correctPasses', 'fouls', 'incorrectPasses', 'offsides', 'redCards', 'shots', 'status', 'stealings', 'yellowCards', 'throwIn', 'goalkick', 'nutmegs', 'sombreros', 'penaltyShootout'])

# %%
data['incidences'].keys()
goals = list(data['incidences']['goals'].items())
goal_list_dicts = [flatten_goal(goal, game_id) for goal in goals]

# %%
goal_df = pd.DataFrame(goal_list_dicts)

# %%
goal_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 2          NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
# 4          NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 2   448588  22825994      54702          9       17
# 3   448588  22826185      47487         11      134
# 4   448588  22826995      77919         13       17

# %%
transpose_test_df = goal_df.copy()

# %%
neg_df = transpose_test_df.loc[transpose_test_df['coord_x1'] < 0]
neg_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 2          NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 4          NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 2   448588  22825994      54702          9       17
# 4   448588  22826995      77919         13       17

# %%
pos_df = transpose_test_df.loc[transpose_test_df['coord_x1'] > 0]
pos_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 3   448588  22826185      47487         11      134

# %% [markdown]
# ### now want to multiply coord_x1, coord_x2, coord_y1, coord_y2 in neg_df by -1

# %%
neg_df.loc[:,['coord_x1', 'coord_x2', 'coord_y1', 'coord_y2']] *= -1
# Out:
# /Users/david/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
neg_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 2          NaN      0.67      0.98     -0.17      0.13        -1      0.18
# 4          NaN      0.73      1.00      0.01     -0.06        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 2   448588  22825994      54702          9       17
# 4   448588  22826995      77919         13       17

# %%
transposed_goal_df = pd.concat([neg_df, pos_df])

# %%
transposed_goal_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 2          NaN      0.67      0.98     -0.17      0.13        -1      0.18
# 4          NaN      0.73      1.00      0.01     -0.06        -1      0.18
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 2   448588  22825994      54702          9       17
# 4   448588  22826995      77919         13       17
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 3   448588  22826185      47487         11      134

# %%
goal_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 2          NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
# 4          NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 2   448588  22825994      54702          9       17
# 3   448588  22826185      47487         11      134
# 4   448588  22826995      77919         13       17

# %%
fig, ax = plt.subplots()
ax.scatter(goal_df['coord_x1'], goal_df['coord_y1'])
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_facecolor('xkcd:lightgreen')

# %%
fig, ax = plt.subplots()
ax.scatter(transposed_goal_df['coord_x1'], transposed_goal_df['coord_y1'])
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_facecolor('xkcd:lightgreen')

# %% [markdown]
# ### think it worked...

# %%
shots = list(data['incidences']['shots'].items())
shot_list_dicts = [flatten_shot(shot, game_id) for shot in shots]
shot_df = pd.DataFrame(shot_list_dicts)

# %%
shots = list(data['incidences']['shots'].items())
shot_list_dicts = [flatten_shot(shot, game_id) for shot in shots]
shot_df = pd.DataFrame(shot_list_dicts)

# %%
shot_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 1         NaN     -0.48     -0.99      0.02     -0.12        -1     -1.00
# 2         NaN     -0.75     -0.99     -0.14      0.21        -1     -1.00
# 3     49859.0     -0.43     -0.96     -0.06      0.07        -1      0.33
# 4         NaN     -0.47     -1.00     -0.17     -0.27        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 6     49859.0     -0.67     -0.94     -0.36     -0.04        -1      0.08
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 9         NaN     -0.85     -0.99      0.31     -0.26        -1     -1.00
# 10    49859.0     -0.46     -0.95      0.00     -0.02        -1      0.08
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 12        NaN     -0.67     -0.98      0.17     -0.13        -1      0.18
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 16        NaN     -0.73     -1.00     -0.01      0.06        -1      0.18
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
# 18        NaN     -0.48     -1.00      0.36      0.07        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588      28126  22822829         33       1      3     30       17
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 5    448588      54702  22823436          9       1     22     30       17
# 6    448588      27793  22823456         35       1     24      1      134
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 11   448588     136947  22825743         33       2     45     39      134
# 12   448588      54702  22825994          9       2     49     18       17
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 16   448588      77919  22826995         13       2     71     26       17
# 17   448588      47487  22827507         33       2     80     53      134
# 18   448588      51413  22827782         33       2     85     12       17
#
#     time_of_event(min)
# 0             3.500000
# 1             6.916667
# 2             7.500000
# 3             8.666667
# 4            10.516667
# 5            22.500000
# 6            24.016667
# 7            32.966667
# 8            34.550000
# 9            36.333333
# 10           44.800000
# 11           45.650000
# 12           49.300000
# 13           53.083333
# 14           57.533333
# 15           65.200000
# 16           71.433333
# 17           80.883333
# 18           85.200000

# %%
transpose_shot_df = shot_df.copy()

# %%
neg_shot_df = transpose_shot_df.loc[transpose_shot_df['coord_x1'] < 0]
pos_shot_df = transpose_shot_df.loc[transpose_shot_df['coord_x1'] > 0]
neg_shot_df.loc[:,['coord_x1', 'coord_x2', 'coord_y1', 'coord_y2']] *= -1
# Out:
# /Users/david/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
transposed_shot_df = pd.concat([neg_shot_df, pos_shot_df])

# %%
transposed_shot_df.head()
# Out:
#    caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 1        NaN      0.48      0.99     -0.02      0.12        -1     -1.00
# 2        NaN      0.75      0.99      0.14     -0.21        -1     -1.00
# 3    49859.0      0.43      0.96      0.06     -0.07        -1      0.33
# 4        NaN      0.47      1.00      0.17      0.27        -1     -1.00
# 6    49859.0      0.67      0.94      0.36      0.04        -1      0.08
#
#    game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 1   448588     136947  22822912         33       1      6     55      134
# 2   448588       1325  22822926         33       1      7     30      134
# 3   448588     118855  22822958         35       1      8     40      134
# 4   448588       1325  22823013         33       1     10     31      134
# 6   448588      27793  22823456         35       1     24      1      134
#
#    time_of_event(min)
# 1            6.916667
# 2            7.500000
# 3            8.666667
# 4           10.516667
# 6           24.016667

# %%
fig, ax = plt.subplots()
ax.scatter(transposed_shot_df['coord_x1'], transposed_shot_df['coord_y1'])
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_facecolor('xkcd:lightgreen')

# %%
fig, ax = plt.subplots()
ax.scatter(shot_df['coord_x1'], shot_df['coord_y1'])
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_facecolor('xkcd:lightgreen')

# %%
transposed_goal_df
# Out:
#    assisted_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 2          NaN      0.67      0.98     -0.17      0.13        -1      0.18
# 4          NaN      0.73      1.00      0.01     -0.06        -1      0.18
# 0      28126.0      0.83      1.00     -0.14      0.08        -1      0.10
# 1          NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 3     118855.0      0.77      0.99     -0.06     -0.11        -1      0.18
#
#    game_id   goal_id  player_id  shot_type  team_id
# 2   448588  22825994      54702          9       17
# 4   448588  22826995      77919         13       17
# 0   448588  22823436      54702          9       17
# 1   448588  22823953      51413         11       17
# 3   448588  22826185      47487         11      134

# %%
transposed_shot_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 1         NaN      0.48      0.99     -0.02      0.12        -1     -1.00
# 2         NaN      0.75      0.99      0.14     -0.21        -1     -1.00
# 3     49859.0      0.43      0.96      0.06     -0.07        -1      0.33
# 4         NaN      0.47      1.00      0.17      0.27        -1     -1.00
# 6     49859.0      0.67      0.94      0.36      0.04        -1      0.08
# 9         NaN      0.85      0.99     -0.31      0.26        -1     -1.00
# 10    49859.0      0.46      0.95     -0.00      0.02        -1      0.08
# 12        NaN      0.67      0.98     -0.17      0.13        -1      0.18
# 16        NaN      0.73      1.00      0.01     -0.06        -1      0.18
# 18        NaN      0.48      1.00     -0.36     -0.07        -1     -1.00
# 0         NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 5         NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 7         NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 8         NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 11        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 13        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 14    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 15    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 17        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 1    448588     136947  22822912         33       1      6     55      134
# 2    448588       1325  22822926         33       1      7     30      134
# 3    448588     118855  22822958         35       1      8     40      134
# 4    448588       1325  22823013         33       1     10     31      134
# 6    448588      27793  22823456         35       1     24      1      134
# 9    448588      27793  22824052         33       1     36     20      134
# 10   448588     122082  22824659         35       1     44     48      134
# 12   448588      54702  22825994          9       2     49     18       17
# 16   448588      77919  22826995         13       2     71     26       17
# 18   448588      51413  22827782         33       2     85     12       17
# 0    448588      28126  22822829         33       1      3     30       17
# 5    448588      54702  22823436          9       1     22     30       17
# 7    448588      46601  22823838         33       1     32     58       17
# 8    448588      51413  22823953         11       1     34     33       17
# 11   448588     136947  22825743         33       2     45     39      134
# 13   448588      47487  22826185         11       2     53      5      134
# 14   448588      47487  22826510         35       2     57     32      134
# 15   448588     176520  22826843         35       2     65     12      134
# 17   448588      47487  22827507         33       2     80     53      134
#
#     time_of_event(min)
# 1             6.916667
# 2             7.500000
# 3             8.666667
# 4            10.516667
# 6            24.016667
# 9            36.333333
# 10           44.800000
# 12           49.300000
# 16           71.433333
# 18           85.200000
# 0             3.500000
# 5            22.500000
# 7            32.966667
# 8            34.550000
# 11           45.650000
# 13           53.083333
# 14           57.533333
# 15           65.200000
# 17           80.883333

# %%
shots_goal_df = pd.merge(transposed_shot_df, transposed_goal_df.loc[:, ['assisted_by', 'player_id', 'game_id', 'coord_x1', 'coord_x2', 'coord_y1', 'coord_y2', 'coord_z1', 'coord_z2']], on=['player_id', 'game_id', 'coord_x1', 'coord_x2', 'coord_y1', 'coord_y2', 'coord_z1', 'coord_z2'], how='left')

# %%
shots_goal_df
# Out:
#     caught_by  coord_x1  coord_x2  coord_y1  coord_y2  coord_z1  coord_z2  \
# 0         NaN      0.48      0.99     -0.02      0.12        -1     -1.00
# 1         NaN      0.75      0.99      0.14     -0.21        -1     -1.00
# 2     49859.0      0.43      0.96      0.06     -0.07        -1      0.33
# 3         NaN      0.47      1.00      0.17      0.27        -1     -1.00
# 4     49859.0      0.67      0.94      0.36      0.04        -1      0.08
# 5         NaN      0.85      0.99     -0.31      0.26        -1     -1.00
# 6     49859.0      0.46      0.95     -0.00      0.02        -1      0.08
# 7         NaN      0.67      0.98     -0.17      0.13        -1      0.18
# 8         NaN      0.73      1.00      0.01     -0.06        -1      0.18
# 9         NaN      0.48      1.00     -0.36     -0.07        -1     -1.00
# 10        NaN      0.75      0.99     -0.07      0.06        -1     -1.00
# 11        NaN      0.83      1.00     -0.14      0.08        -1      0.10
# 12        NaN      0.97      1.00      0.45      0.16        -1     -1.00
# 13        NaN      0.96      1.00     -0.18     -0.11        -1      0.25
# 14        NaN      0.54      1.00     -0.05      0.34        -1     -1.00
# 15        NaN      0.77      0.99     -0.06     -0.11        -1      0.18
# 16    49859.0      0.72      0.97      0.11     -0.02        -1      0.10
# 17    49859.0      0.77      0.97      0.06      0.07        -1      0.36
# 18        NaN      0.79      0.99     -0.09     -0.09        -1     -1.00
#
#     game_id  player_id   shot_id  shot_type  t_half  t_min  t_sec  team_id  \
# 0    448588     136947  22822912         33       1      6     55      134
# 1    448588       1325  22822926         33       1      7     30      134
# 2    448588     118855  22822958         35       1      8     40      134
# 3    448588       1325  22823013         33       1     10     31      134
# 4    448588      27793  22823456         35       1     24      1      134
# 5    448588      27793  22824052         33       1     36     20      134
# 6    448588     122082  22824659         35       1     44     48      134
# 7    448588      54702  22825994          9       2     49     18       17
# 8    448588      77919  22826995         13       2     71     26       17
# 9    448588      51413  22827782         33       2     85     12       17
# 10   448588      28126  22822829         33       1      3     30       17
# 11   448588      54702  22823436          9       1     22     30       17
# 12   448588      46601  22823838         33       1     32     58       17
# 13   448588      51413  22823953         11       1     34     33       17
# 14   448588     136947  22825743         33       2     45     39      134
# 15   448588      47487  22826185         11       2     53      5      134
# 16   448588      47487  22826510         35       2     57     32      134
# 17   448588     176520  22826843         35       2     65     12      134
# 18   448588      47487  22827507         33       2     80     53      134
#
#     time_of_event(min)  assisted_by
# 0             6.916667          NaN
# 1             7.500000          NaN
# 2             8.666667          NaN
# 3            10.516667          NaN
# 4            24.016667          NaN
# 5            36.333333          NaN
# 6            44.800000          NaN
# 7            49.300000          NaN
# 8            71.433333          NaN
# 9            85.200000          NaN
# 10            3.500000          NaN
# 11           22.500000      28126.0
# 12           32.966667          NaN
# 13           34.550000          NaN
# 14           45.650000          NaN
# 15           53.083333     118855.0
# 16           57.533333          NaN
# 17           65.200000          NaN
# 18           80.883333          NaN

# %% [markdown]
# instead of assisted by, just figure out who passed before shot...
